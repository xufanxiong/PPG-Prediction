# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
from keras.callbacks import ModelCheckpoint
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers import AveragePooling1D, Activation, Flatten, Dense
from keras.layers import GlobalMaxPooling1D, Dropout
from keras.layers import GlobalAveragePooling1D, UpSampling1D
from keras.models import Model
from keras.regularizers import l2
from keras.optimizers import SGD, Adam, Nadam, Adamax
from keras.layers.normalization import BatchNormalization
import keras.backend as K
from data_in_2s import data_in, normali
from modify_new import modify_model
from orignal_model import ori_model
#from tqdm import tqdm
#from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
num_test = 1
X_train, y_train = data_in(num_test)

# %%
#Nomalization
y_train = (y_train-50)/150
#X_train = normali(X_train)
print('Shape of X_train is: ' + str(X_train.shape))
print('Shape of y_train is: ' + str(y_train.shape))
# Out:
# Shape of X_train is: (6394, 1000, 5)
# Shape of y_train is: (6394, 1)

# %%
#Import and Split test data

name_x = 'Training_data/DATA_%.2d_TYPE02.mat'%num_test
in_tem_x = sio.loadmat(name_x)['sig']
in_tem_x = in_tem_x.T

name_y = 'Training_data/DATA_%.2d_TYPE02_BPMtrace.mat'%num_test
in_tem_y = sio.loadmat(name_y)['BPM0']

X_test_tem = np.zeros((in_tem_y.shape[0]*2, 125*8, 5))

k = 0

for j in range(in_tem_y.shape[0]*2-1):
	X_test_tem[j, :, :] =  in_tem_x[k:(k+125*8), 1:]
	k += 125

tem_y = np.zeros((in_tem_y.shape[0]*2, 1))
index = [a*2 for a in range(in_tem_y.shape[0])]
tem_y[index] = in_tem_y

for b in range(tem_y.shape[0]-1):
	if tem_y[b] == 0:
		tem_y[b] = (tem_y[b-1] + tem_y[b+1])/2.

y_test = tem_y[:-1, :]
X_test = X_test_tem[:-1, :, :]

y_test = (y_test-50)/150
#X_test = normali(X_test)

print('The shape of X_test is: ' + str(X_test.shape))
print('The shape of y_test is: ' + str(y_test.shape))
# Out:
# The shape of X_test is: (295, 1000, 5)
# The shape of y_test is: (295, 1)

# %%
X_train_PPG = X_train[:, :, :2]
X_train_acc = X_train[:, :, 2:]

# %%
num_in = 1700
print('Heart rate is: ' + str(y_train[num_in]*150+50))
plt.subplot(211)
plt.plot(X_train_PPG[num_in, :, :])
plt.title('PPG')
plt.subplot(212)
plt.plot(X_train_acc[num_in, :, :])
plt.title('acc')
plt.show()
# Out:
# Heart rate is: [ 149.18165]

# %%
fir_model = ori_model((1000, 5), 16)
# Out:
# /media/zhuolun/DATA/Project/Atheros-CSI-Tool-UserSpace-APP/recvCSI/Xiaoshi/Xiong/augment  (1)/augment /orignal_model.py:199: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   model = Model(input=inputs, output=output)

# %%
optm = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=3*10**(-4))
fir_model.compile(loss= "mse", 
              optimizer=optm, 
              metrics=["mse"])

# %%
filepath="weight_troika_ori_2s.hdf5"
checkpoint = ModelCheckpoint(filepath, 
                             monitor='val_mean_squared_error', 
                             verbose=1, 
                             save_best_only=True,
                             mode='min')
callbacks_list = [checkpoint]
history = fir_model.fit(X_train, y_train, 
                    epochs=200, 
                    batch_size=128, 
                    validation_split=0.2, 
                    callbacks=callbacks_list,
                    shuffle=True,
                    verbose=1)
# Out:
# Train on 5115 samples, validate on 1279 samples
# Epoch 1/200
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.5164 - mean_squared_error: 0.0355 - val_loss: 0.5184 - val_mean_squared_error: 0.0394
#
# Epoch 00001: val_mean_squared_error improved from inf to 0.03945, saving model to weight_troika_ori_2s.hdf5
# Epoch 2/200
# 5115/5115 [==============================] - 5s 969us/step - loss: 0.5082 - mean_squared_error: 0.0318 - val_loss: 0.5072 - val_mean_squared_error: 0.0339
#
# Epoch 00002: val_mean_squared_error improved from 0.03945 to 0.03389, saving model to weight_troika_ori_2s.hdf5
# Epoch 3/200
# 5115/5115 [==============================] - 5s 971us/step - loss: 0.4921 - mean_squared_error: 0.0218 - val_loss: 0.5114 - val_mean_squared_error: 0.0446
#
# Epoch 00003: val_mean_squared_error did not improve from 0.03389
# Epoch 4/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.4784 - mean_squared_error: 0.0150 - val_loss: 0.5275 - val_mean_squared_error: 0.0679
#
# Epoch 00004: val_mean_squared_error did not improve from 0.03389
# Epoch 5/200
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.4674 - mean_squared_error: 0.0116 - val_loss: 0.5374 - val_mean_squared_error: 0.0857
#
# Epoch 00005: val_mean_squared_error did not improve from 0.03389
# Epoch 6/200
# 5115/5115 [==============================] - 5s 973us/step - loss: 0.4564 - mean_squared_error: 0.0088 - val_loss: 0.5368 - val_mean_squared_error: 0.0936
#
# Epoch 00006: val_mean_squared_error did not improve from 0.03389
# Epoch 7/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.4461 - mean_squared_error: 0.0073 - val_loss: 0.5285 - val_mean_squared_error: 0.0943
#
# Epoch 00007: val_mean_squared_error did not improve from 0.03389
# Epoch 8/200
# 5115/5115 [==============================] - 5s 973us/step - loss: 0.4356 - mean_squared_error: 0.0060 - val_loss: 0.5279 - val_mean_squared_error: 0.1030
#
# Epoch 00008: val_mean_squared_error did not improve from 0.03389
# Epoch 9/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.4251 - mean_squared_error: 0.0048 - val_loss: 0.5115 - val_mean_squared_error: 0.0962
#
# Epoch 00009: val_mean_squared_error did not improve from 0.03389
# Epoch 10/200
# 5115/5115 [==============================] - 5s 981us/step - loss: 0.4153 - mean_squared_error: 0.0047 - val_loss: 0.5088 - val_mean_squared_error: 0.1032
#
# Epoch 00010: val_mean_squared_error did not improve from 0.03389
# Epoch 11/200
# 5115/5115 [==============================] - 5s 979us/step - loss: 0.4053 - mean_squared_error: 0.0045 - val_loss: 0.4867 - val_mean_squared_error: 0.0910
#
# Epoch 00011: val_mean_squared_error did not improve from 0.03389
# Epoch 12/200
# 5115/5115 [==============================] - 5s 983us/step - loss: 0.3942 - mean_squared_error: 0.0033 - val_loss: 0.4734 - val_mean_squared_error: 0.0876
#
# Epoch 00012: val_mean_squared_error did not improve from 0.03389
# Epoch 13/200
# 5115/5115 [==============================] - 5s 979us/step - loss: 0.3847 - mean_squared_error: 0.0038 - val_loss: 0.4787 - val_mean_squared_error: 0.1029
#
# Epoch 00013: val_mean_squared_error did not improve from 0.03389
# Epoch 14/200
# 5115/5115 [==============================] - 5s 979us/step - loss: 0.3737 - mean_squared_error: 0.0027 - val_loss: 0.4736 - val_mean_squared_error: 0.1079
#
# Epoch 00014: val_mean_squared_error did not improve from 0.03389
# Epoch 15/200
# 5115/5115 [==============================] - 5s 993us/step - loss: 0.3637 - mean_squared_error: 0.0028 - val_loss: 0.4711 - val_mean_squared_error: 0.1153
#
# Epoch 00015: val_mean_squared_error did not improve from 0.03389
# Epoch 16/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.3533 - mean_squared_error: 0.0023 - val_loss: 0.4484 - val_mean_squared_error: 0.1025
#
# Epoch 00016: val_mean_squared_error did not improve from 0.03389
# Epoch 17/200
# 5115/5115 [==============================] - 5s 996us/step - loss: 0.3450 - mean_squared_error: 0.0039 - val_loss: 0.4289 - val_mean_squared_error: 0.0928
#
# Epoch 00017: val_mean_squared_error did not improve from 0.03389
# Epoch 18/200
# 5115/5115 [==============================] - 5s 999us/step - loss: 0.3339 - mean_squared_error: 0.0025 - val_loss: 0.4382 - val_mean_squared_error: 0.1118
#
# Epoch 00018: val_mean_squared_error did not improve from 0.03389
# Epoch 19/200
# 5115/5115 [==============================] - 5s 999us/step - loss: 0.3239 - mean_squared_error: 0.0022 - val_loss: 0.4376 - val_mean_squared_error: 0.1208
#
# Epoch 00019: val_mean_squared_error did not improve from 0.03389
# Epoch 20/200
# 5115/5115 [==============================] - 5s 997us/step - loss: 0.3138 - mean_squared_error: 0.0017 - val_loss: 0.4147 - val_mean_squared_error: 0.1075
#
# Epoch 00020: val_mean_squared_error did not improve from 0.03389
# Epoch 21/200
# 5115/5115 [==============================] - 5s 994us/step - loss: 0.3043 - mean_squared_error: 0.0017 - val_loss: 0.4168 - val_mean_squared_error: 0.1189
#
# Epoch 00021: val_mean_squared_error did not improve from 0.03389
# Epoch 22/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.2951 - mean_squared_error: 0.0016 - val_loss: 0.4107 - val_mean_squared_error: 0.1220
#
# Epoch 00022: val_mean_squared_error did not improve from 0.03389
# Epoch 23/200
# 5115/5115 [==============================] - 5s 999us/step - loss: 0.2861 - mean_squared_error: 0.0018 - val_loss: 0.3962 - val_mean_squared_error: 0.1165
#
# Epoch 00023: val_mean_squared_error did not improve from 0.03389
# Epoch 24/200
# 5115/5115 [==============================] - 5s 992us/step - loss: 0.2770 - mean_squared_error: 0.0016 - val_loss: 0.3923 - val_mean_squared_error: 0.1214
#
# Epoch 00024: val_mean_squared_error did not improve from 0.03389
# Epoch 25/200
# 5115/5115 [==============================] - 5s 979us/step - loss: 0.2709 - mean_squared_error: 0.0042 - val_loss: 0.3400 - val_mean_squared_error: 0.0776
#
# Epoch 00025: val_mean_squared_error did not improve from 0.03389
# Epoch 26/200
# 5115/5115 [==============================] - 5s 984us/step - loss: 0.2630 - mean_squared_error: 0.0046 - val_loss: 0.3343 - val_mean_squared_error: 0.0802
#
# Epoch 00026: val_mean_squared_error did not improve from 0.03389
# Epoch 27/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.2530 - mean_squared_error: 0.0029 - val_loss: 0.3010 - val_mean_squared_error: 0.0551
#
# Epoch 00027: val_mean_squared_error did not improve from 0.03389
# Epoch 28/200
# 5115/5115 [==============================] - 5s 980us/step - loss: 0.2452 - mean_squared_error: 0.0031 - val_loss: 0.2897 - val_mean_squared_error: 0.0517
#
# Epoch 00028: val_mean_squared_error did not improve from 0.03389
# Epoch 29/200
# 5115/5115 [==============================] - 5s 970us/step - loss: 0.2358 - mean_squared_error: 0.0017 - val_loss: 0.2925 - val_mean_squared_error: 0.0623
#
# Epoch 00029: val_mean_squared_error did not improve from 0.03389
# Epoch 30/200
# 5115/5115 [==============================] - 5s 975us/step - loss: 0.2276 - mean_squared_error: 0.0013 - val_loss: 0.3090 - val_mean_squared_error: 0.0866
#
# Epoch 00030: val_mean_squared_error did not improve from 0.03389
# Epoch 31/200
# 5115/5115 [==============================] - 5s 979us/step - loss: 0.2203 - mean_squared_error: 0.0016 - val_loss: 0.2835 - val_mean_squared_error: 0.0686
#
# Epoch 00031: val_mean_squared_error did not improve from 0.03389
# Epoch 32/200
# 5115/5115 [==============================] - 5s 985us/step - loss: 0.2133 - mean_squared_error: 0.0019 - val_loss: 0.2948 - val_mean_squared_error: 0.0872
#
# Epoch 00032: val_mean_squared_error did not improve from 0.03389
# Epoch 33/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.2060 - mean_squared_error: 0.0018 - val_loss: 0.2897 - val_mean_squared_error: 0.0891
#
# Epoch 00033: val_mean_squared_error did not improve from 0.03389
# Epoch 34/200
# 5115/5115 [==============================] - 5s 980us/step - loss: 0.1986 - mean_squared_error: 0.0014 - val_loss: 0.2689 - val_mean_squared_error: 0.0753
#
# Epoch 00034: val_mean_squared_error did not improve from 0.03389
# Epoch 35/200
# 5115/5115 [==============================] - 5s 979us/step - loss: 0.1917 - mean_squared_error: 0.0013 - val_loss: 0.2877 - val_mean_squared_error: 0.1008
#
# Epoch 00035: val_mean_squared_error did not improve from 0.03389
# Epoch 36/200
# 5115/5115 [==============================] - 5s 978us/step - loss: 0.1862 - mean_squared_error: 0.0024 - val_loss: 0.2717 - val_mean_squared_error: 0.0912
#
# Epoch 00036: val_mean_squared_error did not improve from 0.03389
# Epoch 37/200
# 5115/5115 [==============================] - 5s 982us/step - loss: 0.1787 - mean_squared_error: 0.0012 - val_loss: 0.2727 - val_mean_squared_error: 0.0985
#
# Epoch 00037: val_mean_squared_error did not improve from 0.03389
# Epoch 38/200
# 5115/5115 [==============================] - 5s 980us/step - loss: 0.1724 - mean_squared_error: 0.0013 - val_loss: 0.2774 - val_mean_squared_error: 0.1094
#
# Epoch 00038: val_mean_squared_error did not improve from 0.03389
# Epoch 39/200
# 5115/5115 [==============================] - 5s 979us/step - loss: 0.1665 - mean_squared_error: 0.0014 - val_loss: 0.2366 - val_mean_squared_error: 0.0745
#
# Epoch 00039: val_mean_squared_error did not improve from 0.03389
# Epoch 40/200
# 5115/5115 [==============================] - 5s 980us/step - loss: 0.1605 - mean_squared_error: 0.0012 - val_loss: 0.2308 - val_mean_squared_error: 0.0745
#
# Epoch 00040: val_mean_squared_error did not improve from 0.03389
# Epoch 41/200
# 5115/5115 [==============================] - 5s 984us/step - loss: 0.1548 - mean_squared_error: 0.0012 - val_loss: 0.2336 - val_mean_squared_error: 0.0829
#
# Epoch 00041: val_mean_squared_error did not improve from 0.03389
# Epoch 42/200
# 5115/5115 [==============================] - 5s 973us/step - loss: 0.1489 - mean_squared_error: 8.7146e-04 - val_loss: 0.2404 - val_mean_squared_error: 0.0951
#
# Epoch 00042: val_mean_squared_error did not improve from 0.03389
# Epoch 43/200
# 5115/5115 [==============================] - 5s 978us/step - loss: 0.1434 - mean_squared_error: 7.8571e-04 - val_loss: 0.2433 - val_mean_squared_error: 0.1033
#
# Epoch 00043: val_mean_squared_error did not improve from 0.03389
# Epoch 44/200
# 5115/5115 [==============================] - 5s 978us/step - loss: 0.1382 - mean_squared_error: 7.3112e-04 - val_loss: 0.2370 - val_mean_squared_error: 0.1022
#
# Epoch 00044: val_mean_squared_error did not improve from 0.03389
# Epoch 45/200
# 5115/5115 [==============================] - 5s 975us/step - loss: 0.1331 - mean_squared_error: 7.0809e-04 - val_loss: 0.2404 - val_mean_squared_error: 0.1105
#
# Epoch 00045: val_mean_squared_error did not improve from 0.03389
# Epoch 46/200
# 5115/5115 [==============================] - 5s 975us/step - loss: 0.1284 - mean_squared_error: 9.1876e-04 - val_loss: 0.2326 - val_mean_squared_error: 0.1075
#
# Epoch 00046: val_mean_squared_error did not improve from 0.03389
# Epoch 47/200
# 5115/5115 [==============================] - 5s 980us/step - loss: 0.1240 - mean_squared_error: 0.0012 - val_loss: 0.2186 - val_mean_squared_error: 0.0981
#
# Epoch 00047: val_mean_squared_error did not improve from 0.03389
# Epoch 48/200
# 5115/5115 [==============================] - 5s 978us/step - loss: 0.1193 - mean_squared_error: 9.3106e-04 - val_loss: 0.1823 - val_mean_squared_error: 0.0663
#
# Epoch 00048: val_mean_squared_error did not improve from 0.03389
# Epoch 49/200
# 5115/5115 [==============================] - 5s 976us/step - loss: 0.1147 - mean_squared_error: 7.4727e-04 - val_loss: 0.1961 - val_mean_squared_error: 0.0843
#
# Epoch 00049: val_mean_squared_error did not improve from 0.03389
# Epoch 50/200
# 5115/5115 [==============================] - 5s 978us/step - loss: 0.1132 - mean_squared_error: 0.0035 - val_loss: 0.1905 - val_mean_squared_error: 0.0826
#
# Epoch 00050: val_mean_squared_error did not improve from 0.03389
# Epoch 51/200
# 5115/5115 [==============================] - 5s 976us/step - loss: 0.1148 - mean_squared_error: 0.0080 - val_loss: 0.2222 - val_mean_squared_error: 0.1171
#
# Epoch 00051: val_mean_squared_error did not improve from 0.03389
# Epoch 52/200
# 5115/5115 [==============================] - 5s 974us/step - loss: 0.1067 - mean_squared_error: 0.0034 - val_loss: 0.1260 - val_mean_squared_error: 0.0246
#
# Epoch 00052: val_mean_squared_error improved from 0.03389 to 0.02463, saving model to weight_troika_ori_2s.hdf5
# Epoch 53/200
# 5115/5115 [==============================] - 5s 976us/step - loss: 0.1047 - mean_squared_error: 0.0051 - val_loss: 0.1229 - val_mean_squared_error: 0.0251
#
# Epoch 00053: val_mean_squared_error did not improve from 0.02463
# Epoch 54/200
# 5115/5115 [==============================] - 5s 979us/step - loss: 0.1000 - mean_squared_error: 0.0039 - val_loss: 0.1155 - val_mean_squared_error: 0.0211
#
# Epoch 00054: val_mean_squared_error improved from 0.02463 to 0.02111, saving model to weight_troika_ori_2s.hdf5
# Epoch 55/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.0957 - mean_squared_error: 0.0030 - val_loss: 0.1073 - val_mean_squared_error: 0.0164
#
# Epoch 00055: val_mean_squared_error improved from 0.02111 to 0.01638, saving model to weight_troika_ori_2s.hdf5
# Epoch 56/200
# 5115/5115 [==============================] - 5s 975us/step - loss: 0.0911 - mean_squared_error: 0.0018 - val_loss: 0.1021 - val_mean_squared_error: 0.0145
#
# Epoch 00056: val_mean_squared_error improved from 0.01638 to 0.01447, saving model to weight_troika_ori_2s.hdf5
# Epoch 57/200
# 5115/5115 [==============================] - 5s 980us/step - loss: 0.0878 - mean_squared_error: 0.0018 - val_loss: 0.1098 - val_mean_squared_error: 0.0254
#
# Epoch 00057: val_mean_squared_error did not improve from 0.01447
# Epoch 58/200
# 5115/5115 [==============================] - 5s 971us/step - loss: 0.0846 - mean_squared_error: 0.0017 - val_loss: 0.1008 - val_mean_squared_error: 0.0196
#
# Epoch 00058: val_mean_squared_error did not improve from 0.01447
# Epoch 59/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.0816 - mean_squared_error: 0.0018 - val_loss: 0.1024 - val_mean_squared_error: 0.0241
#
# Epoch 00059: val_mean_squared_error did not improve from 0.01447
# Epoch 60/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.0783 - mean_squared_error: 0.0014 - val_loss: 0.1177 - val_mean_squared_error: 0.0423
#
# Epoch 00060: val_mean_squared_error did not improve from 0.01447
# Epoch 61/200
# 5115/5115 [==============================] - 5s 975us/step - loss: 0.0756 - mean_squared_error: 0.0016 - val_loss: 0.1185 - val_mean_squared_error: 0.0459
#
# Epoch 00061: val_mean_squared_error did not improve from 0.01447
# Epoch 62/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.0733 - mean_squared_error: 0.0020 - val_loss: 0.0888 - val_mean_squared_error: 0.0188
#
# Epoch 00062: val_mean_squared_error did not improve from 0.01447
# Epoch 63/200
# 5115/5115 [==============================] - 5s 981us/step - loss: 0.0700 - mean_squared_error: 0.0013 - val_loss: 0.1014 - val_mean_squared_error: 0.0341
#
# Epoch 00063: val_mean_squared_error did not improve from 0.01447
# Epoch 64/200
# 5115/5115 [==============================] - 5s 975us/step - loss: 0.0670 - mean_squared_error: 8.9909e-04 - val_loss: 0.1021 - val_mean_squared_error: 0.0373
#
# Epoch 00064: val_mean_squared_error did not improve from 0.01447
# Epoch 65/200
# 5115/5115 [==============================] - 5s 974us/step - loss: 0.0644 - mean_squared_error: 9.0410e-04 - val_loss: 0.1041 - val_mean_squared_error: 0.0419
#
# Epoch 00065: val_mean_squared_error did not improve from 0.01447
# Epoch 66/200
# 5115/5115 [==============================] - 5s 979us/step - loss: 0.0622 - mean_squared_error: 0.0011 - val_loss: 0.1053 - val_mean_squared_error: 0.0454
#
# Epoch 00066: val_mean_squared_error did not improve from 0.01447
# Epoch 67/200
# 5115/5115 [==============================] - 5s 978us/step - loss: 0.0606 - mean_squared_error: 0.0018 - val_loss: 0.1092 - val_mean_squared_error: 0.0515
#
# Epoch 00067: val_mean_squared_error did not improve from 0.01447
# Epoch 68/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.0587 - mean_squared_error: 0.0020 - val_loss: 0.0885 - val_mean_squared_error: 0.0329
#
# Epoch 00068: val_mean_squared_error did not improve from 0.01447
# Epoch 69/200
# 5115/5115 [==============================] - 5s 975us/step - loss: 0.0568 - mean_squared_error: 0.0022 - val_loss: 0.0778 - val_mean_squared_error: 0.0242
#
# Epoch 00069: val_mean_squared_error did not improve from 0.01447
# Epoch 70/200
# 5115/5115 [==============================] - 5s 975us/step - loss: 0.0543 - mean_squared_error: 0.0016 - val_loss: 0.0778 - val_mean_squared_error: 0.0261
#
# Epoch 00070: val_mean_squared_error did not improve from 0.01447
# Epoch 71/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.0518 - mean_squared_error: 0.0011 - val_loss: 0.0706 - val_mean_squared_error: 0.0209
#
# Epoch 00071: val_mean_squared_error did not improve from 0.01447
# Epoch 72/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.0496 - mean_squared_error: 7.9571e-04 - val_loss: 0.0733 - val_mean_squared_error: 0.0255
#
# Epoch 00072: val_mean_squared_error did not improve from 0.01447
# Epoch 73/200
# 5115/5115 [==============================] - 5s 974us/step - loss: 0.0479 - mean_squared_error: 0.0011 - val_loss: 0.1150 - val_mean_squared_error: 0.0690
#
# Epoch 00073: val_mean_squared_error did not improve from 0.01447
# Epoch 74/200
# 5115/5115 [==============================] - 5s 979us/step - loss: 0.0477 - mean_squared_error: 0.0025 - val_loss: 0.0960 - val_mean_squared_error: 0.0516
#
# Epoch 00074: val_mean_squared_error did not improve from 0.01447
# Epoch 75/200
# 5115/5115 [==============================] - 5s 975us/step - loss: 0.0457 - mean_squared_error: 0.0020 - val_loss: 0.0663 - val_mean_squared_error: 0.0234
#
# Epoch 00075: val_mean_squared_error did not improve from 0.01447
# Epoch 76/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.0444 - mean_squared_error: 0.0023 - val_loss: 0.0613 - val_mean_squared_error: 0.0201
#
# Epoch 00076: val_mean_squared_error did not improve from 0.01447
# Epoch 77/200
# 5115/5115 [==============================] - 5s 982us/step - loss: 0.0416 - mean_squared_error: 0.0011 - val_loss: 0.0566 - val_mean_squared_error: 0.0169
#
# Epoch 00077: val_mean_squared_error did not improve from 0.01447
# Epoch 78/200
# 5115/5115 [==============================] - 5s 985us/step - loss: 0.0397 - mean_squared_error: 7.2203e-04 - val_loss: 0.0609 - val_mean_squared_error: 0.0227
#
# Epoch 00078: val_mean_squared_error did not improve from 0.01447
# Epoch 79/200
# 5115/5115 [==============================] - 5s 980us/step - loss: 0.0381 - mean_squared_error: 6.5167e-04 - val_loss: 0.0652 - val_mean_squared_error: 0.0285
#
# Epoch 00079: val_mean_squared_error did not improve from 0.01447
# Epoch 80/200
# 5115/5115 [==============================] - 5s 982us/step - loss: 0.0365 - mean_squared_error: 6.1054e-04 - val_loss: 0.0683 - val_mean_squared_error: 0.0331
#
# Epoch 00080: val_mean_squared_error did not improve from 0.01447
# Epoch 81/200
# 5115/5115 [==============================] - 5s 979us/step - loss: 0.0351 - mean_squared_error: 6.2440e-04 - val_loss: 0.0702 - val_mean_squared_error: 0.0364
#
# Epoch 00081: val_mean_squared_error did not improve from 0.01447
# Epoch 82/200
# 5115/5115 [==============================] - 5s 979us/step - loss: 0.0337 - mean_squared_error: 6.1388e-04 - val_loss: 0.0720 - val_mean_squared_error: 0.0396
#
# Epoch 00082: val_mean_squared_error did not improve from 0.01447
# Epoch 83/200
# 5115/5115 [==============================] - 5s 978us/step - loss: 0.0324 - mean_squared_error: 6.0865e-04 - val_loss: 0.0755 - val_mean_squared_error: 0.0444
#
# Epoch 00083: val_mean_squared_error did not improve from 0.01447
# Epoch 84/200
# 5115/5115 [==============================] - 5s 973us/step - loss: 0.0311 - mean_squared_error: 5.9186e-04 - val_loss: 0.0746 - val_mean_squared_error: 0.0447
#
# Epoch 00084: val_mean_squared_error did not improve from 0.01447
# Epoch 85/200
# 5115/5115 [==============================] - 5s 978us/step - loss: 0.0299 - mean_squared_error: 5.7644e-04 - val_loss: 0.0799 - val_mean_squared_error: 0.0512
#
# Epoch 00085: val_mean_squared_error did not improve from 0.01447
# Epoch 86/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.0288 - mean_squared_error: 6.8975e-04 - val_loss: 0.0917 - val_mean_squared_error: 0.0641
#
# Epoch 00086: val_mean_squared_error did not improve from 0.01447
# Epoch 87/200
# 5115/5115 [==============================] - 5s 980us/step - loss: 0.0296 - mean_squared_error: 0.0025 - val_loss: 0.0566 - val_mean_squared_error: 0.0298
#
# Epoch 00087: val_mean_squared_error did not improve from 0.01447
# Epoch 88/200
# 5115/5115 [==============================] - 5s 980us/step - loss: 0.0309 - mean_squared_error: 0.0044 - val_loss: 0.1089 - val_mean_squared_error: 0.0827
#
# Epoch 00088: val_mean_squared_error did not improve from 0.01447
# Epoch 89/200
# 5115/5115 [==============================] - 5s 971us/step - loss: 0.0286 - mean_squared_error: 0.0028 - val_loss: 0.0588 - val_mean_squared_error: 0.0334
#
# Epoch 00089: val_mean_squared_error did not improve from 0.01447
# Epoch 90/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.0299 - mean_squared_error: 0.0047 - val_loss: 0.1412 - val_mean_squared_error: 0.1158
#
# Epoch 00090: val_mean_squared_error did not improve from 0.01447
# Epoch 91/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.0314 - mean_squared_error: 0.0058 - val_loss: 0.0758 - val_mean_squared_error: 0.0504
#
# Epoch 00091: val_mean_squared_error did not improve from 0.01447
# Epoch 92/200
# 5115/5115 [==============================] - 5s 978us/step - loss: 0.0285 - mean_squared_error: 0.0034 - val_loss: 0.0622 - val_mean_squared_error: 0.0375
#
# Epoch 00092: val_mean_squared_error did not improve from 0.01447
# Epoch 93/200
# 5115/5115 [==============================] - 5s 978us/step - loss: 0.0263 - mean_squared_error: 0.0020 - val_loss: 0.0474 - val_mean_squared_error: 0.0235
#
# Epoch 00093: val_mean_squared_error did not improve from 0.01447
# Epoch 94/200
# 5115/5115 [==============================] - 5s 980us/step - loss: 0.0249 - mean_squared_error: 0.0015 - val_loss: 0.0518 - val_mean_squared_error: 0.0288
#
# Epoch 00094: val_mean_squared_error did not improve from 0.01447
# Epoch 95/200
# 5115/5115 [==============================] - 5s 979us/step - loss: 0.0241 - mean_squared_error: 0.0015 - val_loss: 0.0395 - val_mean_squared_error: 0.0173
#
# Epoch 00095: val_mean_squared_error did not improve from 0.01447
# Epoch 96/200
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.0230 - mean_squared_error: 0.0012 - val_loss: 0.0382 - val_mean_squared_error: 0.0168
#
# Epoch 00096: val_mean_squared_error did not improve from 0.01447
# Epoch 97/200
# 5115/5115 [==============================] - 5s 974us/step - loss: 0.0219 - mean_squared_error: 8.7670e-04 - val_loss: 0.0400 - val_mean_squared_error: 0.0194
#
# Epoch 00097: val_mean_squared_error did not improve from 0.01447
# Epoch 98/200
# 5115/5115 [==============================] - 5s 994us/step - loss: 0.0215 - mean_squared_error: 0.0013 - val_loss: 0.0348 - val_mean_squared_error: 0.0149
#
# Epoch 00098: val_mean_squared_error did not improve from 0.01447
# Epoch 99/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0206 - mean_squared_error: 0.0010 - val_loss: 0.0350 - val_mean_squared_error: 0.0158
#
# Epoch 00099: val_mean_squared_error did not improve from 0.01447
# Epoch 100/200
# 5115/5115 [==============================] - 5s 992us/step - loss: 0.0214 - mean_squared_error: 0.0024 - val_loss: 0.0527 - val_mean_squared_error: 0.0341
#
# Epoch 00100: val_mean_squared_error did not improve from 0.01447
# Epoch 101/200
# 5115/5115 [==============================] - 5s 986us/step - loss: 0.0203 - mean_squared_error: 0.0019 - val_loss: 0.0386 - val_mean_squared_error: 0.0205
#
# Epoch 00101: val_mean_squared_error did not improve from 0.01447
# Epoch 102/200
# 5115/5115 [==============================] - 5s 988us/step - loss: 0.0189 - mean_squared_error: 0.0011 - val_loss: 0.0371 - val_mean_squared_error: 0.0197
#
# Epoch 00102: val_mean_squared_error did not improve from 0.01447
# Epoch 103/200
# 5115/5115 [==============================] - 5s 988us/step - loss: 0.0182 - mean_squared_error: 0.0010 - val_loss: 0.0369 - val_mean_squared_error: 0.0200
#
# Epoch 00103: val_mean_squared_error did not improve from 0.01447
# Epoch 104/200
# 5115/5115 [==============================] - 5s 985us/step - loss: 0.0173 - mean_squared_error: 7.7517e-04 - val_loss: 0.0392 - val_mean_squared_error: 0.0230
#
# Epoch 00104: val_mean_squared_error did not improve from 0.01447
# Epoch 105/200
# 5115/5115 [==============================] - 5s 989us/step - loss: 0.0167 - mean_squared_error: 7.7568e-04 - val_loss: 0.0534 - val_mean_squared_error: 0.0378
#
# Epoch 00105: val_mean_squared_error did not improve from 0.01447
# Epoch 106/200
# 5115/5115 [==============================] - 5s 987us/step - loss: 0.0166 - mean_squared_error: 0.0013 - val_loss: 0.0854 - val_mean_squared_error: 0.0703
#
# Epoch 00106: val_mean_squared_error did not improve from 0.01447
# Epoch 107/200
# 5115/5115 [==============================] - 5s 986us/step - loss: 0.0167 - mean_squared_error: 0.0018 - val_loss: 0.0365 - val_mean_squared_error: 0.0218
#
# Epoch 00107: val_mean_squared_error did not improve from 0.01447
# Epoch 108/200
# 5115/5115 [==============================] - 5s 987us/step - loss: 0.0158 - mean_squared_error: 0.0014 - val_loss: 0.0480 - val_mean_squared_error: 0.0338
#
# Epoch 00108: val_mean_squared_error did not improve from 0.01447
# Epoch 109/200
# 5115/5115 [==============================] - 5s 992us/step - loss: 0.0151 - mean_squared_error: 0.0012 - val_loss: 0.0421 - val_mean_squared_error: 0.0284
#
# Epoch 00109: val_mean_squared_error did not improve from 0.01447
# Epoch 110/200
# 5115/5115 [==============================] - 5s 991us/step - loss: 0.0149 - mean_squared_error: 0.0014 - val_loss: 0.0303 - val_mean_squared_error: 0.0171
#
# Epoch 00110: val_mean_squared_error did not improve from 0.01447
# Epoch 111/200
# 5115/5115 [==============================] - 5s 982us/step - loss: 0.0171 - mean_squared_error: 0.0039 - val_loss: 0.0908 - val_mean_squared_error: 0.0777
#
# Epoch 00111: val_mean_squared_error did not improve from 0.01447
# Epoch 112/200
# 5115/5115 [==============================] - 5s 987us/step - loss: 0.0155 - mean_squared_error: 0.0025 - val_loss: 0.0478 - val_mean_squared_error: 0.0350
#
# Epoch 00112: val_mean_squared_error did not improve from 0.01447
# Epoch 113/200
# 5115/5115 [==============================] - 5s 991us/step - loss: 0.0147 - mean_squared_error: 0.0021 - val_loss: 0.0357 - val_mean_squared_error: 0.0232
#
# Epoch 00113: val_mean_squared_error did not improve from 0.01447
# Epoch 114/200
# 5115/5115 [==============================] - 5s 987us/step - loss: 0.0147 - mean_squared_error: 0.0024 - val_loss: 0.0263 - val_mean_squared_error: 0.0141
#
# Epoch 00114: val_mean_squared_error improved from 0.01447 to 0.01413, saving model to weight_troika_ori_2s.hdf5
# Epoch 115/200
# 5115/5115 [==============================] - 5s 985us/step - loss: 0.0133 - mean_squared_error: 0.0013 - val_loss: 0.0276 - val_mean_squared_error: 0.0159
#
# Epoch 00115: val_mean_squared_error did not improve from 0.01413
# Epoch 116/200
# 5115/5115 [==============================] - 5s 988us/step - loss: 0.0124 - mean_squared_error: 8.5200e-04 - val_loss: 0.0293 - val_mean_squared_error: 0.0179
#
# Epoch 00116: val_mean_squared_error did not improve from 0.01413
# Epoch 117/200
# 5115/5115 [==============================] - 5s 990us/step - loss: 0.0126 - mean_squared_error: 0.0014 - val_loss: 0.0333 - val_mean_squared_error: 0.0223
#
# Epoch 00117: val_mean_squared_error did not improve from 0.01413
# Epoch 118/200
# 5115/5115 [==============================] - 5s 988us/step - loss: 0.0124 - mean_squared_error: 0.0015 - val_loss: 0.0281 - val_mean_squared_error: 0.0174
#
# Epoch 00118: val_mean_squared_error did not improve from 0.01413
# Epoch 119/200
# 5115/5115 [==============================] - 5s 988us/step - loss: 0.0120 - mean_squared_error: 0.0014 - val_loss: 0.0388 - val_mean_squared_error: 0.0283
#
# Epoch 00119: val_mean_squared_error did not improve from 0.01413
# Epoch 120/200
# 5115/5115 [==============================] - 5s 984us/step - loss: 0.0112 - mean_squared_error: 8.8875e-04 - val_loss: 0.0397 - val_mean_squared_error: 0.0296
#
# Epoch 00120: val_mean_squared_error did not improve from 0.01413
# Epoch 121/200
# 5115/5115 [==============================] - 5s 995us/step - loss: 0.0108 - mean_squared_error: 8.4936e-04 - val_loss: 0.0294 - val_mean_squared_error: 0.0196
#
# Epoch 00121: val_mean_squared_error did not improve from 0.01413
# Epoch 122/200
# 5115/5115 [==============================] - 5s 990us/step - loss: 0.0105 - mean_squared_error: 9.0913e-04 - val_loss: 0.0456 - val_mean_squared_error: 0.0362
#
# Epoch 00122: val_mean_squared_error did not improve from 0.01413
# Epoch 123/200
# 5115/5115 [==============================] - 5s 990us/step - loss: 0.0100 - mean_squared_error: 6.6763e-04 - val_loss: 0.0399 - val_mean_squared_error: 0.0308
#
# Epoch 00123: val_mean_squared_error did not improve from 0.01413
# Epoch 124/200
# 5115/5115 [==============================] - 5s 992us/step - loss: 0.0105 - mean_squared_error: 0.0015 - val_loss: 0.0674 - val_mean_squared_error: 0.0585
#
# Epoch 00124: val_mean_squared_error did not improve from 0.01413
# Epoch 125/200
# 5115/5115 [==============================] - 5s 995us/step - loss: 0.0114 - mean_squared_error: 0.0025 - val_loss: 0.0351 - val_mean_squared_error: 0.0263
#
# Epoch 00125: val_mean_squared_error did not improve from 0.01413
# Epoch 126/200
# 5115/5115 [==============================] - 5s 991us/step - loss: 0.0103 - mean_squared_error: 0.0016 - val_loss: 0.0372 - val_mean_squared_error: 0.0286
#
# Epoch 00126: val_mean_squared_error did not improve from 0.01413
# Epoch 127/200
# 5115/5115 [==============================] - 5s 994us/step - loss: 0.0093 - mean_squared_error: 8.3710e-04 - val_loss: 0.0268 - val_mean_squared_error: 0.0185
#
# Epoch 00127: val_mean_squared_error did not improve from 0.01413
# Epoch 128/200
# 5115/5115 [==============================] - 5s 990us/step - loss: 0.0089 - mean_squared_error: 6.9714e-04 - val_loss: 0.0322 - val_mean_squared_error: 0.0241
#
# Epoch 00128: val_mean_squared_error did not improve from 0.01413
# Epoch 129/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0085 - mean_squared_error: 6.3324e-04 - val_loss: 0.0315 - val_mean_squared_error: 0.0237
#
# Epoch 00129: val_mean_squared_error did not improve from 0.01413
# Epoch 130/200
# 5115/5115 [==============================] - 5s 997us/step - loss: 0.0083 - mean_squared_error: 6.4298e-04 - val_loss: 0.0379 - val_mean_squared_error: 0.0305
#
# Epoch 00130: val_mean_squared_error did not improve from 0.01413
# Epoch 131/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0082 - mean_squared_error: 8.9206e-04 - val_loss: 0.0281 - val_mean_squared_error: 0.0209
#
# Epoch 00131: val_mean_squared_error did not improve from 0.01413
# Epoch 132/200
# 5115/5115 [==============================] - 5s 994us/step - loss: 0.0080 - mean_squared_error: 8.2537e-04 - val_loss: 0.0458 - val_mean_squared_error: 0.0388
#
# Epoch 00132: val_mean_squared_error did not improve from 0.01413
# Epoch 133/200
# 5115/5115 [==============================] - 5s 997us/step - loss: 0.0076 - mean_squared_error: 6.3943e-04 - val_loss: 0.0435 - val_mean_squared_error: 0.0367
#
# Epoch 00133: val_mean_squared_error did not improve from 0.01413
# Epoch 134/200
# 5115/5115 [==============================] - 5s 995us/step - loss: 0.0073 - mean_squared_error: 5.8830e-04 - val_loss: 0.0381 - val_mean_squared_error: 0.0315
#
# Epoch 00134: val_mean_squared_error did not improve from 0.01413
# Epoch 135/200
# 5115/5115 [==============================] - 5s 995us/step - loss: 0.0071 - mean_squared_error: 6.8091e-04 - val_loss: 0.0537 - val_mean_squared_error: 0.0474
#
# Epoch 00135: val_mean_squared_error did not improve from 0.01413
# Epoch 136/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0078 - mean_squared_error: 0.0015 - val_loss: 0.0347 - val_mean_squared_error: 0.0284
#
# Epoch 00136: val_mean_squared_error did not improve from 0.01413
# Epoch 137/200
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0079 - mean_squared_error: 0.0016 - val_loss: 0.0256 - val_mean_squared_error: 0.0194
#
# Epoch 00137: val_mean_squared_error did not improve from 0.01413
# Epoch 138/200
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0078 - mean_squared_error: 0.0016 - val_loss: 0.0187 - val_mean_squared_error: 0.0125
#
# Epoch 00138: val_mean_squared_error improved from 0.01413 to 0.01249, saving model to weight_troika_ori_2s.hdf5
# Epoch 139/200
# 5115/5115 [==============================] - 5s 997us/step - loss: 0.0071 - mean_squared_error: 9.4136e-04 - val_loss: 0.0206 - val_mean_squared_error: 0.0145
#
# Epoch 00139: val_mean_squared_error did not improve from 0.01249
# Epoch 140/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0072 - mean_squared_error: 0.0012 - val_loss: 0.0350 - val_mean_squared_error: 0.0290
#
# Epoch 00140: val_mean_squared_error did not improve from 0.01249
# Epoch 141/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0070 - mean_squared_error: 0.0012 - val_loss: 0.0309 - val_mean_squared_error: 0.0251
#
# Epoch 00141: val_mean_squared_error did not improve from 0.01249
# Epoch 142/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0071 - mean_squared_error: 0.0013 - val_loss: 0.0282 - val_mean_squared_error: 0.0225
#
# Epoch 00142: val_mean_squared_error did not improve from 0.01249
# Epoch 143/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0068 - mean_squared_error: 0.0011 - val_loss: 0.0260 - val_mean_squared_error: 0.0204
#
# Epoch 00143: val_mean_squared_error did not improve from 0.01249
# Epoch 144/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0063 - mean_squared_error: 7.8385e-04 - val_loss: 0.0253 - val_mean_squared_error: 0.0199
#
# Epoch 00144: val_mean_squared_error did not improve from 0.01249
# Epoch 145/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0060 - mean_squared_error: 6.0972e-04 - val_loss: 0.0270 - val_mean_squared_error: 0.0218
#
# Epoch 00145: val_mean_squared_error did not improve from 0.01249
# Epoch 146/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0058 - mean_squared_error: 5.9102e-04 - val_loss: 0.0305 - val_mean_squared_error: 0.0254
#
# Epoch 00146: val_mean_squared_error did not improve from 0.01249
# Epoch 147/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0056 - mean_squared_error: 5.8723e-04 - val_loss: 0.0285 - val_mean_squared_error: 0.0236
#
# Epoch 00147: val_mean_squared_error did not improve from 0.01249
# Epoch 148/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0064 - mean_squared_error: 0.0016 - val_loss: 0.0366 - val_mean_squared_error: 0.0317
#
# Epoch 00148: val_mean_squared_error did not improve from 0.01249
# Epoch 149/200
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0060 - mean_squared_error: 0.0012 - val_loss: 0.0221 - val_mean_squared_error: 0.0173
#
# Epoch 00149: val_mean_squared_error did not improve from 0.01249
# Epoch 150/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0056 - mean_squared_error: 8.1885e-04 - val_loss: 0.0202 - val_mean_squared_error: 0.0155
#
# Epoch 00150: val_mean_squared_error did not improve from 0.01249
# Epoch 151/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0052 - mean_squared_error: 5.9351e-04 - val_loss: 0.0251 - val_mean_squared_error: 0.0205
#
# Epoch 00151: val_mean_squared_error did not improve from 0.01249
# Epoch 152/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0050 - mean_squared_error: 5.5452e-04 - val_loss: 0.0258 - val_mean_squared_error: 0.0214
#
# Epoch 00152: val_mean_squared_error did not improve from 0.01249
# Epoch 153/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0049 - mean_squared_error: 5.4564e-04 - val_loss: 0.0358 - val_mean_squared_error: 0.0316
#
# Epoch 00153: val_mean_squared_error did not improve from 0.01249
# Epoch 154/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0048 - mean_squared_error: 5.5762e-04 - val_loss: 0.0394 - val_mean_squared_error: 0.0352
#
# Epoch 00154: val_mean_squared_error did not improve from 0.01249
# Epoch 155/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0046 - mean_squared_error: 5.5108e-04 - val_loss: 0.0341 - val_mean_squared_error: 0.0301
#
# Epoch 00155: val_mean_squared_error did not improve from 0.01249
# Epoch 156/200
# 5115/5115 [==============================] - 5s 998us/step - loss: 0.0045 - mean_squared_error: 4.9773e-04 - val_loss: 0.0381 - val_mean_squared_error: 0.0342
#
# Epoch 00156: val_mean_squared_error did not improve from 0.01249
# Epoch 157/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0044 - mean_squared_error: 5.7773e-04 - val_loss: 0.0292 - val_mean_squared_error: 0.0255
#
# Epoch 00157: val_mean_squared_error did not improve from 0.01249
# Epoch 158/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0042 - mean_squared_error: 5.0316e-04 - val_loss: 0.0412 - val_mean_squared_error: 0.0375
#
# Epoch 00158: val_mean_squared_error did not improve from 0.01249
# Epoch 159/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0042 - mean_squared_error: 5.8888e-04 - val_loss: 0.0341 - val_mean_squared_error: 0.0305
#
# Epoch 00159: val_mean_squared_error did not improve from 0.01249
# Epoch 160/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0062 - mean_squared_error: 0.0026 - val_loss: 0.0374 - val_mean_squared_error: 0.0336
#
# Epoch 00160: val_mean_squared_error did not improve from 0.01249
# Epoch 161/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0067 - mean_squared_error: 0.0028 - val_loss: 0.0436 - val_mean_squared_error: 0.0396
#
# Epoch 00161: val_mean_squared_error did not improve from 0.01249
# Epoch 162/200
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0072 - mean_squared_error: 0.0031 - val_loss: 0.0351 - val_mean_squared_error: 0.0309
#
# Epoch 00162: val_mean_squared_error did not improve from 0.01249
# Epoch 163/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0057 - mean_squared_error: 0.0015 - val_loss: 0.0364 - val_mean_squared_error: 0.0322
#
# Epoch 00163: val_mean_squared_error did not improve from 0.01249
# Epoch 164/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0066 - mean_squared_error: 0.0024 - val_loss: 0.0306 - val_mean_squared_error: 0.0264
#
# Epoch 00164: val_mean_squared_error did not improve from 0.01249
# Epoch 165/200
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0056 - mean_squared_error: 0.0013 - val_loss: 0.0202 - val_mean_squared_error: 0.0160
#
# Epoch 00165: val_mean_squared_error did not improve from 0.01249
# Epoch 166/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0048 - mean_squared_error: 6.6387e-04 - val_loss: 0.0242 - val_mean_squared_error: 0.0201
#
# Epoch 00166: val_mean_squared_error did not improve from 0.01249
# Epoch 167/200
# 5115/5115 [==============================] - 5s 997us/step - loss: 0.0047 - mean_squared_error: 7.0358e-04 - val_loss: 0.0330 - val_mean_squared_error: 0.0290
#
# Epoch 00167: val_mean_squared_error did not improve from 0.01249
# Epoch 168/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0046 - mean_squared_error: 6.9902e-04 - val_loss: 0.0284 - val_mean_squared_error: 0.0245
#
# Epoch 00168: val_mean_squared_error did not improve from 0.01249
# Epoch 169/200
# 5115/5115 [==============================] - 5s 996us/step - loss: 0.0044 - mean_squared_error: 6.5949e-04 - val_loss: 0.0386 - val_mean_squared_error: 0.0348
#
# Epoch 00169: val_mean_squared_error did not improve from 0.01249
# Epoch 170/200
# 5115/5115 [==============================] - 5s 999us/step - loss: 0.0043 - mean_squared_error: 6.0595e-04 - val_loss: 0.0421 - val_mean_squared_error: 0.0385
#
# Epoch 00170: val_mean_squared_error did not improve from 0.01249
# Epoch 171/200
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0042 - mean_squared_error: 6.1918e-04 - val_loss: 0.0362 - val_mean_squared_error: 0.0326
#
# Epoch 00171: val_mean_squared_error did not improve from 0.01249
# Epoch 172/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0043 - mean_squared_error: 7.7741e-04 - val_loss: 0.0353 - val_mean_squared_error: 0.0319
#
# Epoch 00172: val_mean_squared_error did not improve from 0.01249
# Epoch 173/200
# 5115/5115 [==============================] - 5s 999us/step - loss: 0.0051 - mean_squared_error: 0.0017 - val_loss: 0.0232 - val_mean_squared_error: 0.0197
#
# Epoch 00173: val_mean_squared_error did not improve from 0.01249
# Epoch 174/200
# 5115/5115 [==============================] - 5s 998us/step - loss: 0.0044 - mean_squared_error: 8.5919e-04 - val_loss: 0.0210 - val_mean_squared_error: 0.0175
#
# Epoch 00174: val_mean_squared_error did not improve from 0.01249
# Epoch 175/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0044 - mean_squared_error: 9.3330e-04 - val_loss: 0.0295 - val_mean_squared_error: 0.0260
#
# Epoch 00175: val_mean_squared_error did not improve from 0.01249
# Epoch 176/200
# 5115/5115 [==============================] - 5s 995us/step - loss: 0.0043 - mean_squared_error: 8.6937e-04 - val_loss: 0.0293 - val_mean_squared_error: 0.0260
#
# Epoch 00176: val_mean_squared_error did not improve from 0.01249
# Epoch 177/200
# 5115/5115 [==============================] - 5s 997us/step - loss: 0.0043 - mean_squared_error: 8.9958e-04 - val_loss: 0.0212 - val_mean_squared_error: 0.0179
#
# Epoch 00177: val_mean_squared_error did not improve from 0.01249
# Epoch 178/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0039 - mean_squared_error: 6.4733e-04 - val_loss: 0.0308 - val_mean_squared_error: 0.0275
#
# Epoch 00178: val_mean_squared_error did not improve from 0.01249
# Epoch 179/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0038 - mean_squared_error: 5.8836e-04 - val_loss: 0.0330 - val_mean_squared_error: 0.0298
#
# Epoch 00179: val_mean_squared_error did not improve from 0.01249
# Epoch 180/200
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0038 - mean_squared_error: 6.4189e-04 - val_loss: 0.0419 - val_mean_squared_error: 0.0388
#
# Epoch 00180: val_mean_squared_error did not improve from 0.01249
# Epoch 181/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0036 - mean_squared_error: 5.5651e-04 - val_loss: 0.0336 - val_mean_squared_error: 0.0306
#
# Epoch 00181: val_mean_squared_error did not improve from 0.01249
# Epoch 182/200
# 5115/5115 [==============================] - 5s 998us/step - loss: 0.0035 - mean_squared_error: 5.5731e-04 - val_loss: 0.0316 - val_mean_squared_error: 0.0286
#
# Epoch 00182: val_mean_squared_error did not improve from 0.01249
# Epoch 183/200
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0035 - mean_squared_error: 5.7910e-04 - val_loss: 0.0369 - val_mean_squared_error: 0.0340
#
# Epoch 00183: val_mean_squared_error did not improve from 0.01249
# Epoch 184/200
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0034 - mean_squared_error: 5.4987e-04 - val_loss: 0.0318 - val_mean_squared_error: 0.0290
#
# Epoch 00184: val_mean_squared_error did not improve from 0.01249
# Epoch 185/200
# 5115/5115 [==============================] - 5s 999us/step - loss: 0.0034 - mean_squared_error: 6.1946e-04 - val_loss: 0.0272 - val_mean_squared_error: 0.0244
#
# Epoch 00185: val_mean_squared_error did not improve from 0.01249
# Epoch 186/200
# 5115/5115 [==============================] - 5s 999us/step - loss: 0.0036 - mean_squared_error: 8.0519e-04 - val_loss: 0.0287 - val_mean_squared_error: 0.0259
#
# Epoch 00186: val_mean_squared_error did not improve from 0.01249
# Epoch 187/200
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0051 - mean_squared_error: 0.0022 - val_loss: 0.0367 - val_mean_squared_error: 0.0337
#
# Epoch 00187: val_mean_squared_error did not improve from 0.01249
# Epoch 188/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0051 - mean_squared_error: 0.0020 - val_loss: 0.0441 - val_mean_squared_error: 0.0410
#
# Epoch 00188: val_mean_squared_error did not improve from 0.01249
# Epoch 189/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0056 - mean_squared_error: 0.0023 - val_loss: 0.0310 - val_mean_squared_error: 0.0278
#
# Epoch 00189: val_mean_squared_error did not improve from 0.01249
# Epoch 190/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0057 - mean_squared_error: 0.0024 - val_loss: 0.1117 - val_mean_squared_error: 0.1083
#
# Epoch 00190: val_mean_squared_error did not improve from 0.01249
# Epoch 191/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0063 - mean_squared_error: 0.0027 - val_loss: 0.0470 - val_mean_squared_error: 0.0433
#
# Epoch 00191: val_mean_squared_error did not improve from 0.01249
# Epoch 192/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0053 - mean_squared_error: 0.0016 - val_loss: 0.0476 - val_mean_squared_error: 0.0439
#
# Epoch 00192: val_mean_squared_error did not improve from 0.01249
# Epoch 193/200
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0048 - mean_squared_error: 0.0011 - val_loss: 0.0234 - val_mean_squared_error: 0.0198
#
# Epoch 00193: val_mean_squared_error did not improve from 0.01249
# Epoch 194/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0045 - mean_squared_error: 9.2937e-04 - val_loss: 0.0232 - val_mean_squared_error: 0.0196
#
# Epoch 00194: val_mean_squared_error did not improve from 0.01249
# Epoch 195/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0044 - mean_squared_error: 9.5631e-04 - val_loss: 0.0226 - val_mean_squared_error: 0.0191
#
# Epoch 00195: val_mean_squared_error did not improve from 0.01249
# Epoch 196/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0042 - mean_squared_error: 8.0373e-04 - val_loss: 0.0315 - val_mean_squared_error: 0.0281
#
# Epoch 00196: val_mean_squared_error did not improve from 0.01249
# Epoch 197/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0040 - mean_squared_error: 6.3783e-04 - val_loss: 0.0316 - val_mean_squared_error: 0.0284
#
# Epoch 00197: val_mean_squared_error did not improve from 0.01249
# Epoch 198/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0039 - mean_squared_error: 6.6114e-04 - val_loss: 0.0369 - val_mean_squared_error: 0.0337
#
# Epoch 00198: val_mean_squared_error did not improve from 0.01249
# Epoch 199/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0038 - mean_squared_error: 6.8968e-04 - val_loss: 0.0472 - val_mean_squared_error: 0.0441
#
# Epoch 00199: val_mean_squared_error did not improve from 0.01249
# Epoch 200/200
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0037 - mean_squared_error: 6.2695e-04 - val_loss: 0.0361 - val_mean_squared_error: 0.0330
#
# Epoch 00200: val_mean_squared_error did not improve from 0.01249

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('MSE')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
filepath="weight_troika_ori_2s.hdf5"
fir_model.load_weights(filepath)

# %%
#fir_model.summary()

# %%
#Evaluate
#eva = finalmodel.evaluate(X_test, Y_test, batch_size=32, verbose=1, sample_weight=None)
#print('loss = ' + str(eva[0]))
#print('Test MSE = ' + str(eva[1]))

# %%
pred_label = fir_model.predict(X_train)

# %%
mod_model, y_mod_label = modify_model((1000, 5), y_train, pred_label, 16)
# Out:
# /media/zhuolun/DATA/Project/Atheros-CSI-Tool-UserSpace-APP/recvCSI/Xiaoshi/Xiong/augment  (1)/augment /modify_new.py:201: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   model = Model(input=inputs, output=output)

# %%
optm = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=3*10**(-4))
mod_model.compile(loss= "mse", 
              optimizer=optm, 
              metrics=["mse"])

# %%
filepath="weight_troika_ori_modify_2s.hdf5"
checkpoint = ModelCheckpoint(filepath, 
                             monitor='val_mean_squared_error', 
                             verbose=1, 
                             save_best_only=True,
                             mode='min')
callbacks_list = [checkpoint]
history = mod_model.fit(X_train, y_mod_label, 
                    epochs=100, 
                    batch_size=128, 
                    validation_split=0.2, 
                    callbacks=callbacks_list,
                    shuffle=True,
                    verbose=1)
# Out:
# Train on 5115 samples, validate on 1279 samples
# Epoch 1/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.5896 - mean_squared_error: 0.0828 - val_loss: 0.5216 - val_mean_squared_error: 0.0166
#
# Epoch 00001: val_mean_squared_error improved from inf to 0.01661, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 2/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.5085 - mean_squared_error: 0.0061 - val_loss: 0.5131 - val_mean_squared_error: 0.0137
#
# Epoch 00002: val_mean_squared_error improved from 0.01661 to 0.01374, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 3/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.5014 - mean_squared_error: 0.0053 - val_loss: 0.5057 - val_mean_squared_error: 0.0133
#
# Epoch 00003: val_mean_squared_error improved from 0.01374 to 0.01329, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 4/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.4936 - mean_squared_error: 0.0050 - val_loss: 0.4975 - val_mean_squared_error: 0.0131
#
# Epoch 00004: val_mean_squared_error improved from 0.01329 to 0.01307, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 5/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.4851 - mean_squared_error: 0.0049 - val_loss: 0.4887 - val_mean_squared_error: 0.0130
#
# Epoch 00005: val_mean_squared_error improved from 0.01307 to 0.01295, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 6/100
# 5115/5115 [==============================] - 5s 994us/step - loss: 0.4760 - mean_squared_error: 0.0048 - val_loss: 0.4793 - val_mean_squared_error: 0.0129
#
# Epoch 00006: val_mean_squared_error improved from 0.01295 to 0.01286, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 7/100
# 5115/5115 [==============================] - 5s 996us/step - loss: 0.4664 - mean_squared_error: 0.0047 - val_loss: 0.4694 - val_mean_squared_error: 0.0128
#
# Epoch 00007: val_mean_squared_error improved from 0.01286 to 0.01281, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 8/100
# 5115/5115 [==============================] - 5s 985us/step - loss: 0.4564 - mean_squared_error: 0.0047 - val_loss: 0.4593 - val_mean_squared_error: 0.0128
#
# Epoch 00008: val_mean_squared_error improved from 0.01281 to 0.01276, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 9/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.4461 - mean_squared_error: 0.0046 - val_loss: 0.4489 - val_mean_squared_error: 0.0127
#
# Epoch 00009: val_mean_squared_error improved from 0.01276 to 0.01273, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 10/100
# 5115/5115 [==============================] - 5s 987us/step - loss: 0.4356 - mean_squared_error: 0.0046 - val_loss: 0.4383 - val_mean_squared_error: 0.0127
#
# Epoch 00010: val_mean_squared_error improved from 0.01273 to 0.01271, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 11/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.4250 - mean_squared_error: 0.0046 - val_loss: 0.4276 - val_mean_squared_error: 0.0127
#
# Epoch 00011: val_mean_squared_error improved from 0.01271 to 0.01269, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 12/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.4142 - mean_squared_error: 0.0046 - val_loss: 0.4168 - val_mean_squared_error: 0.0127
#
# Epoch 00012: val_mean_squared_error improved from 0.01269 to 0.01267, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 13/100
# 5115/5115 [==============================] - 5s 987us/step - loss: 0.4034 - mean_squared_error: 0.0045 - val_loss: 0.4060 - val_mean_squared_error: 0.0127
#
# Epoch 00013: val_mean_squared_error improved from 0.01267 to 0.01266, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 14/100
# 5115/5115 [==============================] - 5s 982us/step - loss: 0.3926 - mean_squared_error: 0.0045 - val_loss: 0.3952 - val_mean_squared_error: 0.0126
#
# Epoch 00014: val_mean_squared_error improved from 0.01266 to 0.01265, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 15/100
# 5115/5115 [==============================] - 5s 976us/step - loss: 0.3818 - mean_squared_error: 0.0045 - val_loss: 0.3844 - val_mean_squared_error: 0.0126
#
# Epoch 00015: val_mean_squared_error improved from 0.01265 to 0.01264, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 16/100
# 5115/5115 [==============================] - 5s 987us/step - loss: 0.3711 - mean_squared_error: 0.0045 - val_loss: 0.3738 - val_mean_squared_error: 0.0126
#
# Epoch 00016: val_mean_squared_error improved from 0.01264 to 0.01263, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 17/100
# 5115/5115 [==============================] - 5s 984us/step - loss: 0.3605 - mean_squared_error: 0.0045 - val_loss: 0.3632 - val_mean_squared_error: 0.0126
#
# Epoch 00017: val_mean_squared_error improved from 0.01263 to 0.01263, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 18/100
# 5115/5115 [==============================] - 5s 985us/step - loss: 0.3499 - mean_squared_error: 0.0045 - val_loss: 0.3527 - val_mean_squared_error: 0.0126
#
# Epoch 00018: val_mean_squared_error improved from 0.01263 to 0.01262, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 19/100
# 5115/5115 [==============================] - 5s 988us/step - loss: 0.3395 - mean_squared_error: 0.0045 - val_loss: 0.3424 - val_mean_squared_error: 0.0126
#
# Epoch 00019: val_mean_squared_error improved from 0.01262 to 0.01262, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 20/100
# 5115/5115 [==============================] - 5s 991us/step - loss: 0.3293 - mean_squared_error: 0.0045 - val_loss: 0.3322 - val_mean_squared_error: 0.0126
#
# Epoch 00020: val_mean_squared_error improved from 0.01262 to 0.01261, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 21/100
# 5115/5115 [==============================] - 5s 986us/step - loss: 0.3192 - mean_squared_error: 0.0045 - val_loss: 0.3222 - val_mean_squared_error: 0.0126
#
# Epoch 00021: val_mean_squared_error improved from 0.01261 to 0.01261, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 22/100
# 5115/5115 [==============================] - 5s 977us/step - loss: 0.3093 - mean_squared_error: 0.0045 - val_loss: 0.3124 - val_mean_squared_error: 0.0126
#
# Epoch 00022: val_mean_squared_error improved from 0.01261 to 0.01260, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 23/100
# 5115/5115 [==============================] - 5s 985us/step - loss: 0.2995 - mean_squared_error: 0.0045 - val_loss: 0.3027 - val_mean_squared_error: 0.0126
#
# Epoch 00023: val_mean_squared_error improved from 0.01260 to 0.01260, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 24/100
# 5115/5115 [==============================] - 5s 988us/step - loss: 0.2900 - mean_squared_error: 0.0045 - val_loss: 0.2933 - val_mean_squared_error: 0.0126
#
# Epoch 00024: val_mean_squared_error improved from 0.01260 to 0.01260, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 25/100
# 5115/5115 [==============================] - 5s 985us/step - loss: 0.2806 - mean_squared_error: 0.0045 - val_loss: 0.2840 - val_mean_squared_error: 0.0126
#
# Epoch 00025: val_mean_squared_error improved from 0.01260 to 0.01260, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 26/100
# 5115/5115 [==============================] - 5s 978us/step - loss: 0.2715 - mean_squared_error: 0.0045 - val_loss: 0.2750 - val_mean_squared_error: 0.0126
#
# Epoch 00026: val_mean_squared_error improved from 0.01260 to 0.01259, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 27/100
# 5115/5115 [==============================] - 5s 985us/step - loss: 0.2626 - mean_squared_error: 0.0045 - val_loss: 0.2662 - val_mean_squared_error: 0.0126
#
# Epoch 00027: val_mean_squared_error improved from 0.01259 to 0.01259, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 28/100
# 5115/5115 [==============================] - 5s 976us/step - loss: 0.2539 - mean_squared_error: 0.0045 - val_loss: 0.2576 - val_mean_squared_error: 0.0126
#
# Epoch 00028: val_mean_squared_error did not improve from 0.01259
# Epoch 29/100
# 5115/5115 [==============================] - 5s 984us/step - loss: 0.2454 - mean_squared_error: 0.0045 - val_loss: 0.2492 - val_mean_squared_error: 0.0126
#
# Epoch 00029: val_mean_squared_error improved from 0.01259 to 0.01259, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 30/100
# 5115/5115 [==============================] - 5s 982us/step - loss: 0.2371 - mean_squared_error: 0.0045 - val_loss: 0.2410 - val_mean_squared_error: 0.0126
#
# Epoch 00030: val_mean_squared_error did not improve from 0.01259
# Epoch 31/100
# 5115/5115 [==============================] - 5s 987us/step - loss: 0.2290 - mean_squared_error: 0.0045 - val_loss: 0.2331 - val_mean_squared_error: 0.0126
#
# Epoch 00031: val_mean_squared_error improved from 0.01259 to 0.01259, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 32/100
# 5115/5115 [==============================] - 5s 984us/step - loss: 0.2212 - mean_squared_error: 0.0045 - val_loss: 0.2253 - val_mean_squared_error: 0.0126
#
# Epoch 00032: val_mean_squared_error did not improve from 0.01259
# Epoch 33/100
# 5115/5115 [==============================] - 5s 987us/step - loss: 0.2135 - mean_squared_error: 0.0045 - val_loss: 0.2178 - val_mean_squared_error: 0.0126
#
# Epoch 00033: val_mean_squared_error improved from 0.01259 to 0.01259, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 34/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.2061 - mean_squared_error: 0.0045 - val_loss: 0.2105 - val_mean_squared_error: 0.0126
#
# Epoch 00034: val_mean_squared_error did not improve from 0.01259
# Epoch 35/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.1989 - mean_squared_error: 0.0045 - val_loss: 0.2034 - val_mean_squared_error: 0.0126
#
# Epoch 00035: val_mean_squared_error did not improve from 0.01259
# Epoch 36/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.1919 - mean_squared_error: 0.0045 - val_loss: 0.1966 - val_mean_squared_error: 0.0126
#
# Epoch 00036: val_mean_squared_error did not improve from 0.01259
# Epoch 37/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.1852 - mean_squared_error: 0.0045 - val_loss: 0.1899 - val_mean_squared_error: 0.0126
#
# Epoch 00037: val_mean_squared_error did not improve from 0.01259
# Epoch 38/100
# 5115/5115 [==============================] - 5s 999us/step - loss: 0.1786 - mean_squared_error: 0.0045 - val_loss: 0.1834 - val_mean_squared_error: 0.0126
#
# Epoch 00038: val_mean_squared_error did not improve from 0.01259
# Epoch 39/100
# 5115/5115 [==============================] - 5s 998us/step - loss: 0.1722 - mean_squared_error: 0.0045 - val_loss: 0.1772 - val_mean_squared_error: 0.0126
#
# Epoch 00039: val_mean_squared_error did not improve from 0.01259
# Epoch 40/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.1661 - mean_squared_error: 0.0045 - val_loss: 0.1711 - val_mean_squared_error: 0.0126
#
# Epoch 00040: val_mean_squared_error did not improve from 0.01259
# Epoch 41/100
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.1601 - mean_squared_error: 0.0045 - val_loss: 0.1652 - val_mean_squared_error: 0.0126
#
# Epoch 00041: val_mean_squared_error did not improve from 0.01259
# Epoch 42/100
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.1543 - mean_squared_error: 0.0045 - val_loss: 0.1595 - val_mean_squared_error: 0.0126
#
# Epoch 00042: val_mean_squared_error did not improve from 0.01259
# Epoch 43/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.1487 - mean_squared_error: 0.0045 - val_loss: 0.1540 - val_mean_squared_error: 0.0126
#
# Epoch 00043: val_mean_squared_error did not improve from 0.01259
# Epoch 44/100
# 5115/5115 [==============================] - 5s 995us/step - loss: 0.1433 - mean_squared_error: 0.0045 - val_loss: 0.1487 - val_mean_squared_error: 0.0126
#
# Epoch 00044: val_mean_squared_error did not improve from 0.01259
# Epoch 45/100
# 5115/5115 [==============================] - 5s 997us/step - loss: 0.1381 - mean_squared_error: 0.0045 - val_loss: 0.1436 - val_mean_squared_error: 0.0126
#
# Epoch 00045: val_mean_squared_error did not improve from 0.01259
# Epoch 46/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.1330 - mean_squared_error: 0.0045 - val_loss: 0.1386 - val_mean_squared_error: 0.0126
#
# Epoch 00046: val_mean_squared_error did not improve from 0.01259
# Epoch 47/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.1281 - mean_squared_error: 0.0045 - val_loss: 0.1338 - val_mean_squared_error: 0.0126
#
# Epoch 00047: val_mean_squared_error did not improve from 0.01259
# Epoch 48/100
# 5115/5115 [==============================] - 5s 996us/step - loss: 0.1234 - mean_squared_error: 0.0045 - val_loss: 0.1292 - val_mean_squared_error: 0.0126
#
# Epoch 00048: val_mean_squared_error did not improve from 0.01259
# Epoch 49/100
# 5115/5115 [==============================] - 5s 998us/step - loss: 0.1189 - mean_squared_error: 0.0045 - val_loss: 0.1247 - val_mean_squared_error: 0.0126
#
# Epoch 00049: val_mean_squared_error did not improve from 0.01259
# Epoch 50/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.1145 - mean_squared_error: 0.0045 - val_loss: 0.1204 - val_mean_squared_error: 0.0126
#
# Epoch 00050: val_mean_squared_error did not improve from 0.01259
# Epoch 51/100
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.1102 - mean_squared_error: 0.0045 - val_loss: 0.1163 - val_mean_squared_error: 0.0126
#
# Epoch 00051: val_mean_squared_error did not improve from 0.01259
# Epoch 52/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.1061 - mean_squared_error: 0.0045 - val_loss: 0.1122 - val_mean_squared_error: 0.0126
#
# Epoch 00052: val_mean_squared_error did not improve from 0.01259
# Epoch 53/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.1022 - mean_squared_error: 0.0045 - val_loss: 0.1084 - val_mean_squared_error: 0.0126
#
# Epoch 00053: val_mean_squared_error did not improve from 0.01259
# Epoch 54/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0984 - mean_squared_error: 0.0045 - val_loss: 0.1046 - val_mean_squared_error: 0.0126
#
# Epoch 00054: val_mean_squared_error did not improve from 0.01259
# Epoch 55/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0947 - mean_squared_error: 0.0044 - val_loss: 0.1010 - val_mean_squared_error: 0.0126
#
# Epoch 00055: val_mean_squared_error did not improve from 0.01259
# Epoch 56/100
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0912 - mean_squared_error: 0.0044 - val_loss: 0.0976 - val_mean_squared_error: 0.0126
#
# Epoch 00056: val_mean_squared_error did not improve from 0.01259
# Epoch 57/100
# 5115/5115 [==============================] - 5s 996us/step - loss: 0.0877 - mean_squared_error: 0.0044 - val_loss: 0.0943 - val_mean_squared_error: 0.0126
#
# Epoch 00057: val_mean_squared_error did not improve from 0.01259
# Epoch 58/100
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0846 - mean_squared_error: 0.0045 - val_loss: 0.0911 - val_mean_squared_error: 0.0126
#
# Epoch 00058: val_mean_squared_error did not improve from 0.01259
# Epoch 59/100
# 5115/5115 [==============================] - 5s 994us/step - loss: 0.0814 - mean_squared_error: 0.0045 - val_loss: 0.0880 - val_mean_squared_error: 0.0126
#
# Epoch 00059: val_mean_squared_error did not improve from 0.01259
# Epoch 60/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0783 - mean_squared_error: 0.0045 - val_loss: 0.0850 - val_mean_squared_error: 0.0126
#
# Epoch 00060: val_mean_squared_error did not improve from 0.01259
# Epoch 61/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0754 - mean_squared_error: 0.0045 - val_loss: 0.0821 - val_mean_squared_error: 0.0126
#
# Epoch 00061: val_mean_squared_error did not improve from 0.01259
# Epoch 62/100
# 5115/5115 [==============================] - 5s 995us/step - loss: 0.0726 - mean_squared_error: 0.0045 - val_loss: 0.0793 - val_mean_squared_error: 0.0126
#
# Epoch 00062: val_mean_squared_error did not improve from 0.01259
# Epoch 63/100
# 5115/5115 [==============================] - 5s 998us/step - loss: 0.0698 - mean_squared_error: 0.0045 - val_loss: 0.0766 - val_mean_squared_error: 0.0126
#
# Epoch 00063: val_mean_squared_error did not improve from 0.01259
# Epoch 64/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0672 - mean_squared_error: 0.0045 - val_loss: 0.0741 - val_mean_squared_error: 0.0126
#
# Epoch 00064: val_mean_squared_error did not improve from 0.01259
# Epoch 65/100
# 5115/5115 [==============================] - 5s 995us/step - loss: 0.0647 - mean_squared_error: 0.0045 - val_loss: 0.0716 - val_mean_squared_error: 0.0126
#
# Epoch 00065: val_mean_squared_error did not improve from 0.01259
# Epoch 66/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0623 - mean_squared_error: 0.0045 - val_loss: 0.0692 - val_mean_squared_error: 0.0126
#
# Epoch 00066: val_mean_squared_error did not improve from 0.01259
# Epoch 67/100
# 5115/5115 [==============================] - 5s 992us/step - loss: 0.0599 - mean_squared_error: 0.0045 - val_loss: 0.0669 - val_mean_squared_error: 0.0126
#
# Epoch 00067: val_mean_squared_error did not improve from 0.01259
# Epoch 68/100
# 5115/5115 [==============================] - 5s 1000us/step - loss: 0.0577 - mean_squared_error: 0.0044 - val_loss: 0.0648 - val_mean_squared_error: 0.0127
#
# Epoch 00068: val_mean_squared_error did not improve from 0.01259
# Epoch 69/100
# 5115/5115 [==============================] - 5s 994us/step - loss: 0.0554 - mean_squared_error: 0.0044 - val_loss: 0.0631 - val_mean_squared_error: 0.0131
#
# Epoch 00069: val_mean_squared_error did not improve from 0.01259
# Epoch 70/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0535 - mean_squared_error: 0.0044 - val_loss: 0.0605 - val_mean_squared_error: 0.0124
#
# Epoch 00070: val_mean_squared_error improved from 0.01259 to 0.01244, saving model to weight_troika_ori_modify_2s.hdf5
# Epoch 71/100
# 5115/5115 [==============================] - 5s 995us/step - loss: 0.0515 - mean_squared_error: 0.0044 - val_loss: 0.0591 - val_mean_squared_error: 0.0130
#
# Epoch 00071: val_mean_squared_error did not improve from 0.01244
# Epoch 72/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0496 - mean_squared_error: 0.0044 - val_loss: 0.0575 - val_mean_squared_error: 0.0132
#
# Epoch 00072: val_mean_squared_error did not improve from 0.01244
# Epoch 73/100
# 5115/5115 [==============================] - 5s 997us/step - loss: 0.0478 - mean_squared_error: 0.0044 - val_loss: 0.0549 - val_mean_squared_error: 0.0125
#
# Epoch 00073: val_mean_squared_error did not improve from 0.01244
# Epoch 74/100
# 5115/5115 [==============================] - 5s 991us/step - loss: 0.0460 - mean_squared_error: 0.0043 - val_loss: 0.0532 - val_mean_squared_error: 0.0125
#
# Epoch 00074: val_mean_squared_error did not improve from 0.01244
# Epoch 75/100
# 5115/5115 [==============================] - 5s 998us/step - loss: 0.0442 - mean_squared_error: 0.0042 - val_loss: 0.0516 - val_mean_squared_error: 0.0125
#
# Epoch 00075: val_mean_squared_error did not improve from 0.01244
# Epoch 76/100
# 5115/5115 [==============================] - 5s 999us/step - loss: 0.0426 - mean_squared_error: 0.0043 - val_loss: 0.0501 - val_mean_squared_error: 0.0126
#
# Epoch 00076: val_mean_squared_error did not improve from 0.01244
# Epoch 77/100
# 5115/5115 [==============================] - 5s 999us/step - loss: 0.0412 - mean_squared_error: 0.0045 - val_loss: 0.0489 - val_mean_squared_error: 0.0129
#
# Epoch 00077: val_mean_squared_error did not improve from 0.01244
# Epoch 78/100
# 5115/5115 [==============================] - 5s 994us/step - loss: 0.0395 - mean_squared_error: 0.0042 - val_loss: 0.0697 - val_mean_squared_error: 0.0352
#
# Epoch 00078: val_mean_squared_error did not improve from 0.01244
# Epoch 79/100
# 5115/5115 [==============================] - 5s 996us/step - loss: 0.0383 - mean_squared_error: 0.0045 - val_loss: 0.0458 - val_mean_squared_error: 0.0127
#
# Epoch 00079: val_mean_squared_error did not improve from 0.01244
# Epoch 80/100
# 5115/5115 [==============================] - 5s 994us/step - loss: 0.0369 - mean_squared_error: 0.0044 - val_loss: 0.0445 - val_mean_squared_error: 0.0128
#
# Epoch 00080: val_mean_squared_error did not improve from 0.01244
# Epoch 81/100
# 5115/5115 [==============================] - 5s 994us/step - loss: 0.0355 - mean_squared_error: 0.0044 - val_loss: 0.0432 - val_mean_squared_error: 0.0128
#
# Epoch 00081: val_mean_squared_error did not improve from 0.01244
# Epoch 82/100
# 5115/5115 [==============================] - 5s 996us/step - loss: 0.0342 - mean_squared_error: 0.0044 - val_loss: 0.0423 - val_mean_squared_error: 0.0132
#
# Epoch 00082: val_mean_squared_error did not improve from 0.01244
# Epoch 83/100
# 5115/5115 [==============================] - 5s 994us/step - loss: 0.0329 - mean_squared_error: 0.0044 - val_loss: 0.0410 - val_mean_squared_error: 0.0130
#
# Epoch 00083: val_mean_squared_error did not improve from 0.01244
# Epoch 84/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0317 - mean_squared_error: 0.0044 - val_loss: 0.0415 - val_mean_squared_error: 0.0147
#
# Epoch 00084: val_mean_squared_error did not improve from 0.01244
# Epoch 85/100
# 5115/5115 [==============================] - 5s 999us/step - loss: 0.0304 - mean_squared_error: 0.0042 - val_loss: 0.0465 - val_mean_squared_error: 0.0209
#
# Epoch 00085: val_mean_squared_error did not improve from 0.01244
# Epoch 86/100
# 5115/5115 [==============================] - 5s 993us/step - loss: 0.0291 - mean_squared_error: 0.0039 - val_loss: 0.0640 - val_mean_squared_error: 0.0394
#
# Epoch 00086: val_mean_squared_error did not improve from 0.01244
# Epoch 87/100
# 5115/5115 [==============================] - 5s 994us/step - loss: 0.0282 - mean_squared_error: 0.0041 - val_loss: 0.0390 - val_mean_squared_error: 0.0154
#
# Epoch 00087: val_mean_squared_error did not improve from 0.01244
# Epoch 88/100
# 5115/5115 [==============================] - 5s 992us/step - loss: 0.0268 - mean_squared_error: 0.0037 - val_loss: 0.0517 - val_mean_squared_error: 0.0290
#
# Epoch 00088: val_mean_squared_error did not improve from 0.01244
# Epoch 89/100
# 5115/5115 [==============================] - 5s 995us/step - loss: 0.0262 - mean_squared_error: 0.0040 - val_loss: 0.0343 - val_mean_squared_error: 0.0125
#
# Epoch 00089: val_mean_squared_error did not improve from 0.01244
# Epoch 90/100
# 5115/5115 [==============================] - 5s 995us/step - loss: 0.0257 - mean_squared_error: 0.0044 - val_loss: 0.0337 - val_mean_squared_error: 0.0128
#
# Epoch 00090: val_mean_squared_error did not improve from 0.01244
# Epoch 91/100
# 5115/5115 [==============================] - 5s 988us/step - loss: 0.0244 - mean_squared_error: 0.0041 - val_loss: 0.0330 - val_mean_squared_error: 0.0130
#
# Epoch 00091: val_mean_squared_error did not improve from 0.01244
# Epoch 92/100
# 5115/5115 [==============================] - 5s 990us/step - loss: 0.0233 - mean_squared_error: 0.0037 - val_loss: 0.0489 - val_mean_squared_error: 0.0298
#
# Epoch 00092: val_mean_squared_error did not improve from 0.01244
# Epoch 93/100
# 5115/5115 [==============================] - 5s 998us/step - loss: 0.0225 - mean_squared_error: 0.0037 - val_loss: 0.0319 - val_mean_squared_error: 0.0135
#
# Epoch 00093: val_mean_squared_error did not improve from 0.01244
# Epoch 94/100
# 5115/5115 [==============================] - 5s 991us/step - loss: 0.0217 - mean_squared_error: 0.0037 - val_loss: 0.0305 - val_mean_squared_error: 0.0129
#
# Epoch 00094: val_mean_squared_error did not improve from 0.01244
# Epoch 95/100
# 5115/5115 [==============================] - 5s 994us/step - loss: 0.0208 - mean_squared_error: 0.0036 - val_loss: 0.0299 - val_mean_squared_error: 0.0130
#
# Epoch 00095: val_mean_squared_error did not improve from 0.01244
# Epoch 96/100
# 5115/5115 [==============================] - 5s 991us/step - loss: 0.0199 - mean_squared_error: 0.0034 - val_loss: 0.0298 - val_mean_squared_error: 0.0137
#
# Epoch 00096: val_mean_squared_error did not improve from 0.01244
# Epoch 97/100
# 5115/5115 [==============================] - 5s 1ms/step - loss: 0.0195 - mean_squared_error: 0.0037 - val_loss: 0.0281 - val_mean_squared_error: 0.0126
#
# Epoch 00097: val_mean_squared_error did not improve from 0.01244
# Epoch 98/100
# 5115/5115 [==============================] - 5s 995us/step - loss: 0.0185 - mean_squared_error: 0.0034 - val_loss: 0.0277 - val_mean_squared_error: 0.0128
#
# Epoch 00098: val_mean_squared_error did not improve from 0.01244
# Epoch 99/100
# 5115/5115 [==============================] - 5s 989us/step - loss: 0.0181 - mean_squared_error: 0.0036 - val_loss: 0.0270 - val_mean_squared_error: 0.0128
#
# Epoch 00099: val_mean_squared_error did not improve from 0.01244
# Epoch 100/100
# 5115/5115 [==============================] - 5s 996us/step - loss: 0.0174 - mean_squared_error: 0.0034 - val_loss: 0.0262 - val_mean_squared_error: 0.0126
#
# Epoch 00100: val_mean_squared_error did not improve from 0.01244

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('MSE')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
mod_model.load_weights('weight_troika_ori_modify_2s.hdf5')

# %%
predict = fir_model.predict(X_test)
predict_mod = mod_model.predict(X_test)

# %%
plt.subplot(211)
plt.plot(y_test)
plt.plot(predict)
plt.title('Before modify')
plt.subplot(212)
plt.plot(y_test)
plt.plot(predict+predict_mod)
plt.title('After modify')
plt.show()

# %%
Y_error = abs(y_test - (predict+predict_mod)) * 150
print('The avarage predict error: ', np.mean(Y_error))
# Out:
# The avarage predict error:  4.58520022002

# %%
Y_error = abs(y_test - predict) * 150
print('The avarage predict error: ', np.mean(Y_error))
# Out:
# The avarage predict error:  4.48244501303
