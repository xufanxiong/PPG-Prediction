# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
from autoencoder import autoencoder
from keras.callbacks import ModelCheckpoint
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers import AveragePooling1D, Activation, Flatten, Dense
from keras.layers import GlobalMaxPooling1D, Dropout
from keras.layers import GlobalAveragePooling1D, UpSampling1D
from keras.models import Model
from keras.regularizers import l2
from keras.optimizers import SGD, Adam, Nadam, Adamax
from keras.layers.normalization import BatchNormalization
import keras.backend as K
from data_in import data_in, normali
from modify_model import modify_model
#from tqdm import tqdm
#from sklearn.model_selection import train_test_split
# Out:
# /Users/xufanxiong/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
X_train, y_train = data_in()

# %%
#Nomalization
y_train = (y_train-50)/150
X_train = normali(X_train)
print('Shape of X_train is: ' + str(X_train.shape))
print('Shape of y_train is: ' + str(y_train.shape))
# Out:
# Shape of X_train is: (3203, 1000, 5)
# Shape of y_train is: (3203, 1)

# %%
X_train_PPG = X_train[:, :, :2]
X_train_acc = X_train[:, :, 2:]

# %%
num_in = 1000
print('Heart rate is: ' + str(y_train[num_in]*150+50))
plt.subplot(211)
plt.plot(X_train_PPG[num_in, :, :])
plt.title('PPG')
plt.subplot(212)
plt.plot(X_train_acc[num_in, :, :])
plt.title('acc')
plt.show()
# Out:
# Heart rate is: [0.70401107]

# %%
#Add Gaussian Noise
sigma = 0.0005
mu = 0
noise = np.random.randn(X_train.shape[0], X_train.shape[1], X_train.shape[2])*sigma + mu
noise[:, :, 2:] = 0
X_train_noise = X_train + noise
X_train_noise = X_train_noise / (X_train_noise.max() - X_train_noise.min())

# %%
num_in = 10
print('Heart rate is: ' + str(y_train[num_in]*150+50))
plt.subplot(211)
plt.plot(X_train_noise[num_in, :, :])
plt.title('PPG')
plt.subplot(212)
plt.plot(X_train[num_in, :, :])
plt.title('acc')
plt.show()
# Out:
# Heart rate is: [79.5990566]

# %%
aemodel = autoencoder((1000, 5))

# %%
optm = Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=3*10**(-4))
aemodel.compile(loss= "mse", 
              optimizer=optm, 
              metrics=["mse"])

# %%
filepath="weight_troika.hdf5"
checkpoint = ModelCheckpoint(filepath, 
                             monitor='val_mean_squared_error', 
                             verbose=1, 
                             save_best_only=True,
                             mode='min')
callbacks_list = [checkpoint]
history = aemodel.fit(X_train_noise, X_train, 
                    epochs=200, 
                    batch_size=128, 
                    validation_split=0.2, 
                    callbacks=callbacks_list,
                    shuffle=True,
                    verbose=1)
# Out:
# Train on 1414 samples, validate on 354 samples
# Epoch 1/200
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.0516 - mean_squared_error: 0.0094 - val_loss: 0.0541 - val_mean_squared_error: 0.0122
#
# Epoch 00001: val_mean_squared_error improved from inf to 0.01218, saving model to weight_troika.hdf5
# Epoch 2/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0508 - mean_squared_error: 0.0092 - val_loss: 0.0531 - val_mean_squared_error: 0.0121
#
# Epoch 00002: val_mean_squared_error improved from 0.01218 to 0.01209, saving model to weight_troika.hdf5
# Epoch 3/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0497 - mean_squared_error: 0.0091 - val_loss: 0.0520 - val_mean_squared_error: 0.0121
#
# Epoch 00003: val_mean_squared_error did not improve from 0.01209
# Epoch 4/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0484 - mean_squared_error: 0.0090 - val_loss: 0.0507 - val_mean_squared_error: 0.0121
#
# Epoch 00004: val_mean_squared_error did not improve from 0.01209
# Epoch 5/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0469 - mean_squared_error: 0.0088 - val_loss: 0.0489 - val_mean_squared_error: 0.0117
#
# Epoch 00005: val_mean_squared_error improved from 0.01209 to 0.01169, saving model to weight_troika.hdf5
# Epoch 6/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0451 - mean_squared_error: 0.0085 - val_loss: 0.0477 - val_mean_squared_error: 0.0119
#
# Epoch 00006: val_mean_squared_error did not improve from 0.01169
# Epoch 7/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0432 - mean_squared_error: 0.0080 - val_loss: 0.0450 - val_mean_squared_error: 0.0107
#
# Epoch 00007: val_mean_squared_error improved from 0.01169 to 0.01074, saving model to weight_troika.hdf5
# Epoch 8/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0413 - mean_squared_error: 0.0076 - val_loss: 0.0440 - val_mean_squared_error: 0.0113
#
# Epoch 00008: val_mean_squared_error did not improve from 0.01074
# Epoch 9/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0395 - mean_squared_error: 0.0074 - val_loss: 0.0418 - val_mean_squared_error: 0.0106
#
# Epoch 00009: val_mean_squared_error improved from 0.01074 to 0.01060, saving model to weight_troika.hdf5
# Epoch 10/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0377 - mean_squared_error: 0.0072 - val_loss: 0.0398 - val_mean_squared_error: 0.0101
#
# Epoch 00010: val_mean_squared_error improved from 0.01060 to 0.01015, saving model to weight_troika.hdf5
# Epoch 11/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0360 - mean_squared_error: 0.0070 - val_loss: 0.0385 - val_mean_squared_error: 0.0104
#
# Epoch 00011: val_mean_squared_error did not improve from 0.01015
# Epoch 12/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0342 - mean_squared_error: 0.0068 - val_loss: 0.0364 - val_mean_squared_error: 0.0098
#
# Epoch 00012: val_mean_squared_error improved from 0.01015 to 0.00981, saving model to weight_troika.hdf5
# Epoch 13/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0324 - mean_squared_error: 0.0064 - val_loss: 0.0345 - val_mean_squared_error: 0.0094
#
# Epoch 00013: val_mean_squared_error improved from 0.00981 to 0.00939, saving model to weight_troika.hdf5
# Epoch 14/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0304 - mean_squared_error: 0.0060 - val_loss: 0.0323 - val_mean_squared_error: 0.0087
#
# Epoch 00014: val_mean_squared_error improved from 0.00939 to 0.00867, saving model to weight_troika.hdf5
# Epoch 15/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0286 - mean_squared_error: 0.0055 - val_loss: 0.0327 - val_mean_squared_error: 0.0105
#
# Epoch 00015: val_mean_squared_error did not improve from 0.00867
# Epoch 16/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0269 - mean_squared_error: 0.0052 - val_loss: 0.0297 - val_mean_squared_error: 0.0088
#
# Epoch 00016: val_mean_squared_error did not improve from 0.00867
# Epoch 17/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0252 - mean_squared_error: 0.0048 - val_loss: 0.0276 - val_mean_squared_error: 0.0080
#
# Epoch 00017: val_mean_squared_error improved from 0.00867 to 0.00796, saving model to weight_troika.hdf5
# Epoch 18/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0237 - mean_squared_error: 0.0046 - val_loss: 0.0253 - val_mean_squared_error: 0.0069
#
# Epoch 00018: val_mean_squared_error improved from 0.00796 to 0.00692, saving model to weight_troika.hdf5
# Epoch 19/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0224 - mean_squared_error: 0.0045 - val_loss: 0.0245 - val_mean_squared_error: 0.0072
#
# Epoch 00019: val_mean_squared_error did not improve from 0.00692
# Epoch 20/200
# 1414/1414 [==============================] - 5s 4ms/step - loss: 0.0211 - mean_squared_error: 0.0043 - val_loss: 0.0232 - val_mean_squared_error: 0.0071
#
# Epoch 00020: val_mean_squared_error did not improve from 0.00692
# Epoch 21/200
# 1414/1414 [==============================] - 5s 4ms/step - loss: 0.0198 - mean_squared_error: 0.0042 - val_loss: 0.0220 - val_mean_squared_error: 0.0070
#
# Epoch 00021: val_mean_squared_error did not improve from 0.00692
# Epoch 22/200
# 1414/1414 [==============================] - 5s 4ms/step - loss: 0.0187 - mean_squared_error: 0.0041 - val_loss: 0.0213 - val_mean_squared_error: 0.0073
#
# Epoch 00022: val_mean_squared_error did not improve from 0.00692
# Epoch 23/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0176 - mean_squared_error: 0.0041 - val_loss: 0.0195 - val_mean_squared_error: 0.0065
#
# Epoch 00023: val_mean_squared_error improved from 0.00692 to 0.00652, saving model to weight_troika.hdf5
# Epoch 24/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0167 - mean_squared_error: 0.0040 - val_loss: 0.0186 - val_mean_squared_error: 0.0065
#
# Epoch 00024: val_mean_squared_error improved from 0.00652 to 0.00648, saving model to weight_troika.hdf5
# Epoch 25/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0157 - mean_squared_error: 0.0040 - val_loss: 0.0178 - val_mean_squared_error: 0.0065
#
# Epoch 00025: val_mean_squared_error did not improve from 0.00648
# Epoch 26/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0149 - mean_squared_error: 0.0039 - val_loss: 0.0168 - val_mean_squared_error: 0.0063
#
# Epoch 00026: val_mean_squared_error improved from 0.00648 to 0.00630, saving model to weight_troika.hdf5
# Epoch 27/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0140 - mean_squared_error: 0.0038 - val_loss: 0.0177 - val_mean_squared_error: 0.0079
#
# Epoch 00027: val_mean_squared_error did not improve from 0.00630
# Epoch 28/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0133 - mean_squared_error: 0.0038 - val_loss: 0.0156 - val_mean_squared_error: 0.0066
#
# Epoch 00028: val_mean_squared_error did not improve from 0.00630
# Epoch 29/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0125 - mean_squared_error: 0.0037 - val_loss: 0.0148 - val_mean_squared_error: 0.0064
#
# Epoch 00029: val_mean_squared_error did not improve from 0.00630
# Epoch 30/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0119 - mean_squared_error: 0.0037 - val_loss: 0.0140 - val_mean_squared_error: 0.0062
#
# Epoch 00030: val_mean_squared_error improved from 0.00630 to 0.00617, saving model to weight_troika.hdf5
# Epoch 31/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0112 - mean_squared_error: 0.0037 - val_loss: 0.0142 - val_mean_squared_error: 0.0069
#
# Epoch 00031: val_mean_squared_error did not improve from 0.00617
# Epoch 32/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0107 - mean_squared_error: 0.0036 - val_loss: 0.0144 - val_mean_squared_error: 0.0076
#
# Epoch 00032: val_mean_squared_error did not improve from 0.00617
# Epoch 33/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0102 - mean_squared_error: 0.0036 - val_loss: 0.0126 - val_mean_squared_error: 0.0063
# Epoch 00033: val_mean_squared_error did not improve from 0.00617
# Epoch 34/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0096 - mean_squared_error: 0.0035 - val_loss: 0.0129 - val_mean_squared_error: 0.0070
#
# Epoch 00034: val_mean_squared_error did not improve from 0.00617
# Epoch 35/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0092 - mean_squared_error: 0.0035 - val_loss: 0.0112 - val_mean_squared_error: 0.0058
#
# Epoch 00035: val_mean_squared_error improved from 0.00617 to 0.00576, saving model to weight_troika.hdf5
# Epoch 36/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0088 - mean_squared_error: 0.0035 - val_loss: 0.0113 - val_mean_squared_error: 0.0062
#
# Epoch 00036: val_mean_squared_error did not improve from 0.00576
# Epoch 37/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0084 - mean_squared_error: 0.0035 - val_loss: 0.0114 - val_mean_squared_error: 0.0066
#
# Epoch 00037: val_mean_squared_error did not improve from 0.00576
# Epoch 38/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0080 - mean_squared_error: 0.0033 - val_loss: 0.0108 - val_mean_squared_error: 0.0063
#
# Epoch 00038: val_mean_squared_error did not improve from 0.00576
# Epoch 39/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0077 - mean_squared_error: 0.0033 - val_loss: 0.0117 - val_mean_squared_error: 0.0075
#
# Epoch 00039: val_mean_squared_error did not improve from 0.00576
# Epoch 40/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0074 - mean_squared_error: 0.0034 - val_loss: 0.0099 - val_mean_squared_error: 0.0060
#
# Epoch 00040: val_mean_squared_error did not improve from 0.00576
# Epoch 41/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0071 - mean_squared_error: 0.0033 - val_loss: 0.0105 - val_mean_squared_error: 0.0068
#
# Epoch 00041: val_mean_squared_error did not improve from 0.00576
# Epoch 42/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0068 - mean_squared_error: 0.0032 - val_loss: 0.0108 - val_mean_squared_error: 0.0073
#
# Epoch 00042: val_mean_squared_error did not improve from 0.00576
# Epoch 43/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0066 - mean_squared_error: 0.0032 - val_loss: 0.0100 - val_mean_squared_error: 0.0067
#
# Epoch 00043: val_mean_squared_error did not improve from 0.00576
# Epoch 44/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0064 - mean_squared_error: 0.0032 - val_loss: 0.0095 - val_mean_squared_error: 0.0064
#
# Epoch 00044: val_mean_squared_error did not improve from 0.00576
# Epoch 45/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0063 - mean_squared_error: 0.0032 - val_loss: 0.0105 - val_mean_squared_error: 0.0075
#
# Epoch 00045: val_mean_squared_error did not improve from 0.00576
# Epoch 46/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0061 - mean_squared_error: 0.0032 - val_loss: 0.0090 - val_mean_squared_error: 0.0061
#
# Epoch 00046: val_mean_squared_error did not improve from 0.00576
# Epoch 47/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0060 - mean_squared_error: 0.0032 - val_loss: 0.0090 - val_mean_squared_error: 0.0063
#
# Epoch 00047: val_mean_squared_error did not improve from 0.00576
# Epoch 48/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0057 - mean_squared_error: 0.0031 - val_loss: 0.0089 - val_mean_squared_error: 0.0064
#
# Epoch 00048: val_mean_squared_error did not improve from 0.00576
# Epoch 49/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0056 - mean_squared_error: 0.0031 - val_loss: 0.0100 - val_mean_squared_error: 0.0075
#
# Epoch 00049: val_mean_squared_error did not improve from 0.00576
# Epoch 50/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0055 - mean_squared_error: 0.0031 - val_loss: 0.0097 - val_mean_squared_error: 0.0074
#
# Epoch 00050: val_mean_squared_error did not improve from 0.00576
# Epoch 51/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0054 - mean_squared_error: 0.0031 - val_loss: 0.0089 - val_mean_squared_error: 0.0066
#
# Epoch 00051: val_mean_squared_error did not improve from 0.00576
# Epoch 52/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0053 - mean_squared_error: 0.0030 - val_loss: 0.0077 - val_mean_squared_error: 0.0055
#
# Epoch 00052: val_mean_squared_error improved from 0.00576 to 0.00550, saving model to weight_troika.hdf5
# Epoch 53/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0053 - mean_squared_error: 0.0031 - val_loss: 0.0088 - val_mean_squared_error: 0.0067
#
# Epoch 00053: val_mean_squared_error did not improve from 0.00550
# Epoch 54/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0051 - mean_squared_error: 0.0030 - val_loss: 0.0091 - val_mean_squared_error: 0.0071
#
# Epoch 00054: val_mean_squared_error did not improve from 0.00550
# Epoch 55/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0051 - mean_squared_error: 0.0031 - val_loss: 0.0081 - val_mean_squared_error: 0.0061
#
# Epoch 00055: val_mean_squared_error did not improve from 0.00550
# Epoch 56/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0050 - mean_squared_error: 0.0030 - val_loss: 0.0091 - val_mean_squared_error: 0.0071
#
# Epoch 00056: val_mean_squared_error did not improve from 0.00550
# Epoch 57/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0049 - mean_squared_error: 0.0030 - val_loss: 0.0081 - val_mean_squared_error: 0.0062
#
# Epoch 00057: val_mean_squared_error did not improve from 0.00550
# Epoch 58/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0049 - mean_squared_error: 0.0031 - val_loss: 0.0083 - val_mean_squared_error: 0.0064
#
# Epoch 00058: val_mean_squared_error did not improve from 0.00550
# Epoch 59/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0048 - mean_squared_error: 0.0030 - val_loss: 0.0091 - val_mean_squared_error: 0.0073
#
# Epoch 00059: val_mean_squared_error did not improve from 0.00550
# Epoch 60/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0048 - mean_squared_error: 0.0030 - val_loss: 0.0087 - val_mean_squared_error: 0.0069
#
# Epoch 00060: val_mean_squared_error did not improve from 0.00550
# Epoch 61/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0047 - mean_squared_error: 0.0030 - val_loss: 0.0088 - val_mean_squared_error: 0.0071
#
# Epoch 00061: val_mean_squared_error did not improve from 0.00550
# Epoch 62/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0047 - mean_squared_error: 0.0030 - val_loss: 0.0086 - val_mean_squared_error: 0.0069
#
# Epoch 00062: val_mean_squared_error did not improve from 0.00550
# Epoch 63/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0047 - mean_squared_error: 0.0030 - val_loss: 0.0082 - val_mean_squared_error: 0.0065
#
# Epoch 00063: val_mean_squared_error did not improve from 0.00550
# Epoch 64/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0047 - mean_squared_error: 0.0030 - val_loss: 0.0092 - val_mean_squared_error: 0.0075
#
# Epoch 00064: val_mean_squared_error did not improve from 0.00550
# Epoch 65/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0047 - mean_squared_error: 0.0030 - val_loss: 0.0076 - val_mean_squared_error: 0.0059
#
# Epoch 00065: val_mean_squared_error did not improve from 0.00550
# Epoch 66/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0047 - mean_squared_error: 0.0030 - val_loss: 0.0078 - val_mean_squared_error: 0.0061
#
# Epoch 00066: val_mean_squared_error did not improve from 0.00550
# Epoch 67/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0047 - mean_squared_error: 0.0031 - val_loss: 0.0081 - val_mean_squared_error: 0.0064
#
# Epoch 00067: val_mean_squared_error did not improve from 0.00550
# Epoch 68/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0046 - mean_squared_error: 0.0030 - val_loss: 0.0084 - val_mean_squared_error: 0.0067
# Epoch 00068: val_mean_squared_error did not improve from 0.00550
# Epoch 69/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0046 - mean_squared_error: 0.0030 - val_loss: 0.0074 - val_mean_squared_error: 0.0058
#
# Epoch 00069: val_mean_squared_error did not improve from 0.00550
# Epoch 70/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0046 - mean_squared_error: 0.0030 - val_loss: 0.0096 - val_mean_squared_error: 0.0081
#
# Epoch 00070: val_mean_squared_error did not improve from 0.00550
# Epoch 71/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0046 - mean_squared_error: 0.0030 - val_loss: 0.0088 - val_mean_squared_error: 0.0073
#
# Epoch 00071: val_mean_squared_error did not improve from 0.00550
# Epoch 72/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0046 - mean_squared_error: 0.0030 - val_loss: 0.0091 - val_mean_squared_error: 0.0075
#
# Epoch 00072: val_mean_squared_error did not improve from 0.00550
# Epoch 73/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0046 - mean_squared_error: 0.0030 - val_loss: 0.0072 - val_mean_squared_error: 0.0056
#
# Epoch 00073: val_mean_squared_error did not improve from 0.00550
# Epoch 74/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0046 - mean_squared_error: 0.0031 - val_loss: 0.0083 - val_mean_squared_error: 0.0067
#
# Epoch 00074: val_mean_squared_error did not improve from 0.00550
# Epoch 75/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0045 - mean_squared_error: 0.0030 - val_loss: 0.0076 - val_mean_squared_error: 0.0060
#
# Epoch 00075: val_mean_squared_error did not improve from 0.00550
# Epoch 76/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0045 - mean_squared_error: 0.0029 - val_loss: 0.0085 - val_mean_squared_error: 0.0069
#
# Epoch 00076: val_mean_squared_error did not improve from 0.00550
# Epoch 77/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0045 - mean_squared_error: 0.0029 - val_loss: 0.0093 - val_mean_squared_error: 0.0078
#
# Epoch 00077: val_mean_squared_error did not improve from 0.00550
# Epoch 78/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0046 - mean_squared_error: 0.0031 - val_loss: 0.0085 - val_mean_squared_error: 0.0070
#
# Epoch 00078: val_mean_squared_error did not improve from 0.00550
# Epoch 79/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0045 - mean_squared_error: 0.0029 - val_loss: 0.0079 - val_mean_squared_error: 0.0064
#
# Epoch 00079: val_mean_squared_error did not improve from 0.00550
# Epoch 80/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0091 - val_mean_squared_error: 0.0076
#
# Epoch 00080: val_mean_squared_error did not improve from 0.00550
# Epoch 81/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0045 - mean_squared_error: 0.0029 - val_loss: 0.0089 - val_mean_squared_error: 0.0074
#
# Epoch 00081: val_mean_squared_error did not improve from 0.00550
# Epoch 82/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0087 - val_mean_squared_error: 0.0072
#
# Epoch 00082: val_mean_squared_error did not improve from 0.00550
# Epoch 83/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0078 - val_mean_squared_error: 0.0063
#
# Epoch 00083: val_mean_squared_error did not improve from 0.00550
# Epoch 84/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0080 - val_mean_squared_error: 0.0065
#
# Epoch 00084: val_mean_squared_error did not improve from 0.00550
# Epoch 85/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0045 - mean_squared_error: 0.0030 - val_loss: 0.0089 - val_mean_squared_error: 0.0074
#
# Epoch 00085: val_mean_squared_error did not improve from 0.00550
# Epoch 86/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0079 - val_mean_squared_error: 0.0064
#
# Epoch 00086: val_mean_squared_error did not improve from 0.00550
# Epoch 87/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0078 - val_mean_squared_error: 0.0063
#
# Epoch 00087: val_mean_squared_error did not improve from 0.00550
# Epoch 88/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0077 - val_mean_squared_error: 0.0062
#
# Epoch 00088: val_mean_squared_error did not improve from 0.00550
# Epoch 89/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0082 - val_mean_squared_error: 0.0067
#
# Epoch 00089: val_mean_squared_error did not improve from 0.00550
# Epoch 90/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0085 - val_mean_squared_error: 0.0070
#
# Epoch 00090: val_mean_squared_error did not improve from 0.00550
# Epoch 91/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0088 - val_mean_squared_error: 0.0073
#
# Epoch 00091: val_mean_squared_error did not improve from 0.00550
# Epoch 92/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0029 - val_loss: 0.0095 - val_mean_squared_error: 0.0080
#
# Epoch 00092: val_mean_squared_error did not improve from 0.00550
# Epoch 93/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0030 - val_loss: 0.0080 - val_mean_squared_error: 0.0065
#
# Epoch 00093: val_mean_squared_error did not improve from 0.00550
# Epoch 94/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0082 - val_mean_squared_error: 0.0067
#
# Epoch 00094: val_mean_squared_error did not improve from 0.00550
# Epoch 95/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0029 - val_loss: 0.0083 - val_mean_squared_error: 0.0068
#
# Epoch 00095: val_mean_squared_error did not improve from 0.00550
# Epoch 96/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0090 - val_mean_squared_error: 0.0076
#
# Epoch 00096: val_mean_squared_error did not improve from 0.00550
# Epoch 97/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0073 - val_mean_squared_error: 0.0059
#
# Epoch 00097: val_mean_squared_error did not improve from 0.00550
# Epoch 98/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0090 - val_mean_squared_error: 0.0075
#
# Epoch 00098: val_mean_squared_error did not improve from 0.00550
# Epoch 99/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0093 - val_mean_squared_error: 0.0078
#
# Epoch 00099: val_mean_squared_error did not improve from 0.00550
# Epoch 100/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0099 - val_mean_squared_error: 0.0084
#
# Epoch 00100: val_mean_squared_error did not improve from 0.00550
# Epoch 101/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0045 - mean_squared_error: 0.0031 - val_loss: 0.0086 - val_mean_squared_error: 0.0071
#
# Epoch 00101: val_mean_squared_error did not improve from 0.00550
# Epoch 102/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0045 - mean_squared_error: 0.0030 - val_loss: 0.0088 - val_mean_squared_error: 0.0073
#
# Epoch 00102: val_mean_squared_error did not improve from 0.00550
# Epoch 103/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0078 - val_mean_squared_error: 0.0063
#
# Epoch 00103: val_mean_squared_error did not improve from 0.00550
# Epoch 104/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0085 - val_mean_squared_error: 0.0070
#
# Epoch 00104: val_mean_squared_error did not improve from 0.00550
# Epoch 105/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0073 - val_mean_squared_error: 0.0058
#
# Epoch 00105: val_mean_squared_error did not improve from 0.00550
# Epoch 106/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0083 - val_mean_squared_error: 0.0068
#
# Epoch 00106: val_mean_squared_error did not improve from 0.00550
# Epoch 107/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0072 - val_mean_squared_error: 0.0057
#
# Epoch 00107: val_mean_squared_error did not improve from 0.00550
# Epoch 108/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0081 - val_mean_squared_error: 0.0066
#
# Epoch 00108: val_mean_squared_error did not improve from 0.00550
# Epoch 109/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0089 - val_mean_squared_error: 0.0074
#
# Epoch 00109: val_mean_squared_error did not improve from 0.00550
# Epoch 110/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0081 - val_mean_squared_error: 0.0066
#
# Epoch 00110: val_mean_squared_error did not improve from 0.00550
# Epoch 111/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0084 - val_mean_squared_error: 0.0069
#
# Epoch 00111: val_mean_squared_error did not improve from 0.00550
# Epoch 112/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0089 - val_mean_squared_error: 0.0074
#
# Epoch 00112: val_mean_squared_error did not improve from 0.00550
# Epoch 113/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0083 - val_mean_squared_error: 0.0068
#
# Epoch 00113: val_mean_squared_error did not improve from 0.00550
# Epoch 114/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0029 - val_loss: 0.0076 - val_mean_squared_error: 0.0061
#
# Epoch 00114: val_mean_squared_error did not improve from 0.00550
# Epoch 115/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0029 - val_loss: 0.0097 - val_mean_squared_error: 0.0082
#
# Epoch 00115: val_mean_squared_error did not improve from 0.00550
# Epoch 116/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0045 - mean_squared_error: 0.0030 - val_loss: 0.0086 - val_mean_squared_error: 0.0071
#
# Epoch 00116: val_mean_squared_error did not improve from 0.00550
# Epoch 117/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0073 - val_mean_squared_error: 0.0058
#
# Epoch 00117: val_mean_squared_error did not improve from 0.00550
# Epoch 118/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0074 - val_mean_squared_error: 0.0059
#
# Epoch 00118: val_mean_squared_error did not improve from 0.00550
# Epoch 119/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0083 - val_mean_squared_error: 0.0068
#
# Epoch 00119: val_mean_squared_error did not improve from 0.00550
# Epoch 120/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0082 - val_mean_squared_error: 0.0067
#
# Epoch 00120: val_mean_squared_error did not improve from 0.00550
# Epoch 121/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0082 - val_mean_squared_error: 0.0067
#
# Epoch 00121: val_mean_squared_error did not improve from 0.00550
# Epoch 122/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0081 - val_mean_squared_error: 0.0067
#
# Epoch 00122: val_mean_squared_error did not improve from 0.00550
# Epoch 123/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0090 - val_mean_squared_error: 0.0076
#
# Epoch 00123: val_mean_squared_error did not improve from 0.00550
# Epoch 124/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0072 - val_mean_squared_error: 0.0057
#
# Epoch 00124: val_mean_squared_error did not improve from 0.00550
# Epoch 125/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0029 - val_loss: 0.0090 - val_mean_squared_error: 0.0075
#
# Epoch 00125: val_mean_squared_error did not improve from 0.00550
# Epoch 126/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0080 - val_mean_squared_error: 0.0065
#
# Epoch 00126: val_mean_squared_error did not improve from 0.00550
# Epoch 127/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0083 - val_mean_squared_error: 0.0068
#
# Epoch 00127: val_mean_squared_error did not improve from 0.00550
# Epoch 128/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0090 - val_mean_squared_error: 0.0075
#
# Epoch 00128: val_mean_squared_error did not improve from 0.00550
# Epoch 129/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0046 - mean_squared_error: 0.0031 - val_loss: 0.0089 - val_mean_squared_error: 0.0075
#
# Epoch 00129: val_mean_squared_error did not improve from 0.00550
# Epoch 130/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0080 - val_mean_squared_error: 0.0065
#
# Epoch 00130: val_mean_squared_error did not improve from 0.00550
# Epoch 131/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0084 - val_mean_squared_error: 0.0069
#
# Epoch 00131: val_mean_squared_error did not improve from 0.00550
# Epoch 132/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0081 - val_mean_squared_error: 0.0066
#
# Epoch 00132: val_mean_squared_error did not improve from 0.00550
# Epoch 133/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0082 - val_mean_squared_error: 0.0067
#
# Epoch 00133: val_mean_squared_error did not improve from 0.00550
# Epoch 134/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0080 - val_mean_squared_error: 0.0065
#
# Epoch 00134: val_mean_squared_error did not improve from 0.00550
# Epoch 135/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0094 - val_mean_squared_error: 0.0079
#
# Epoch 00135: val_mean_squared_error did not improve from 0.00550
# Epoch 136/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0084 - val_mean_squared_error: 0.0069
#
# Epoch 00136: val_mean_squared_error did not improve from 0.00550
# Epoch 137/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0046 - mean_squared_error: 0.0031 - val_loss: 0.0069 - val_mean_squared_error: 0.0054
#
# Epoch 00137: val_mean_squared_error improved from 0.00550 to 0.00540, saving model to weight_troika.hdf5
# Epoch 138/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0045 - mean_squared_error: 0.0030 - val_loss: 0.0087 - val_mean_squared_error: 0.0072
#
# Epoch 00138: val_mean_squared_error did not improve from 0.00540
# Epoch 139/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0088 - val_mean_squared_error: 0.0073
#
# Epoch 00139: val_mean_squared_error did not improve from 0.00540
# Epoch 140/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0093 - val_mean_squared_error: 0.0078
#
# Epoch 00140: val_mean_squared_error did not improve from 0.00540
# Epoch 141/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0029 - val_loss: 0.0081 - val_mean_squared_error: 0.0066
#
# Epoch 00141: val_mean_squared_error did not improve from 0.00540
# Epoch 142/200
# 1414/1414 [==============================] - 5s 4ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0085 - val_mean_squared_error: 0.0071
#
# Epoch 00142: val_mean_squared_error did not improve from 0.00540
# Epoch 143/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0090 - val_mean_squared_error: 0.0075
#
# Epoch 00143: val_mean_squared_error did not improve from 0.00540
# Epoch 144/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0093 - val_mean_squared_error: 0.0078
#
# Epoch 00144: val_mean_squared_error did not improve from 0.00540
# Epoch 145/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0083 - val_mean_squared_error: 0.0068
#
# Epoch 00145: val_mean_squared_error did not improve from 0.00540
# Epoch 146/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0079 - val_mean_squared_error: 0.0064
#
# Epoch 00146: val_mean_squared_error did not improve from 0.00540
# Epoch 147/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0086 - val_mean_squared_error: 0.0071
#
# Epoch 00147: val_mean_squared_error did not improve from 0.00540
# Epoch 148/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0081 - val_mean_squared_error: 0.0067
#
# Epoch 00148: val_mean_squared_error did not improve from 0.00540
# Epoch 149/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0085 - val_mean_squared_error: 0.0070
#
# Epoch 00149: val_mean_squared_error did not improve from 0.00540
# Epoch 150/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0080 - val_mean_squared_error: 0.0065
#
# Epoch 00150: val_mean_squared_error did not improve from 0.00540
# Epoch 151/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0079 - val_mean_squared_error: 0.0064
#
# Epoch 00151: val_mean_squared_error did not improve from 0.00540
# Epoch 152/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0070 - val_mean_squared_error: 0.0056
#
# Epoch 00152: val_mean_squared_error did not improve from 0.00540
# Epoch 153/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0079 - val_mean_squared_error: 0.0064
#
# Epoch 00153: val_mean_squared_error did not improve from 0.00540
# Epoch 154/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0074 - val_mean_squared_error: 0.0059
#
# Epoch 00154: val_mean_squared_error did not improve from 0.00540
# Epoch 155/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0089 - val_mean_squared_error: 0.0075
#
# Epoch 00155: val_mean_squared_error did not improve from 0.00540
# Epoch 156/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0089 - val_mean_squared_error: 0.0074
#
# Epoch 00156: val_mean_squared_error did not improve from 0.00540
# Epoch 157/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0082 - val_mean_squared_error: 0.0067
#
# Epoch 00157: val_mean_squared_error did not improve from 0.00540
# Epoch 158/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0086 - val_mean_squared_error: 0.0071
#
# Epoch 00158: val_mean_squared_error did not improve from 0.00540
# Epoch 159/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0074 - val_mean_squared_error: 0.0059
#
# Epoch 00159: val_mean_squared_error did not improve from 0.00540
# Epoch 160/200
# 1414/1414 [==============================] - 5s 4ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0078 - val_mean_squared_error: 0.0063
#
# Epoch 00160: val_mean_squared_error did not improve from 0.00540
# Epoch 161/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0075 - val_mean_squared_error: 0.0060
#
# Epoch 00161: val_mean_squared_error did not improve from 0.00540
# Epoch 162/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0089 - val_mean_squared_error: 0.0074
#
# Epoch 00162: val_mean_squared_error did not improve from 0.00540
# Epoch 163/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0081 - val_mean_squared_error: 0.0066
#
# Epoch 00163: val_mean_squared_error did not improve from 0.00540
# Epoch 164/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0087 - val_mean_squared_error: 0.0072
#
# Epoch 00164: val_mean_squared_error did not improve from 0.00540
# Epoch 165/200
# 1414/1414 [==============================] - 5s 4ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0080 - val_mean_squared_error: 0.0065
#
# Epoch 00165: val_mean_squared_error did not improve from 0.00540
# Epoch 166/200
# 1414/1414 [==============================] - 5s 4ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0081 - val_mean_squared_error: 0.0066
#
# Epoch 00166: val_mean_squared_error did not improve from 0.00540
# Epoch 167/200
# 1414/1414 [==============================] - 5s 4ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0074 - val_mean_squared_error: 0.0059
#
# Epoch 00167: val_mean_squared_error did not improve from 0.00540
# Epoch 168/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0083 - val_mean_squared_error: 0.0068
#
# Epoch 00168: val_mean_squared_error did not improve from 0.00540
# Epoch 169/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0073 - val_mean_squared_error: 0.0058
#
# Epoch 00169: val_mean_squared_error did not improve from 0.00540
# Epoch 170/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0072 - val_mean_squared_error: 0.0057
#
# Epoch 00170: val_mean_squared_error did not improve from 0.00540
# Epoch 171/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0090 - val_mean_squared_error: 0.0075
#
# Epoch 00171: val_mean_squared_error did not improve from 0.00540
# Epoch 172/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0045 - mean_squared_error: 0.0030 - val_loss: 0.0085 - val_mean_squared_error: 0.0070
#
# Epoch 00172: val_mean_squared_error did not improve from 0.00540
# Epoch 173/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0071 - val_mean_squared_error: 0.0056
#
# Epoch 00173: val_mean_squared_error did not improve from 0.00540
# Epoch 174/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0045 - mean_squared_error: 0.0030 - val_loss: 0.0075 - val_mean_squared_error: 0.0060
#
# Epoch 00174: val_mean_squared_error did not improve from 0.00540
# Epoch 175/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0086 - val_mean_squared_error: 0.0071
#
# Epoch 00175: val_mean_squared_error did not improve from 0.00540
# Epoch 176/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0081 - val_mean_squared_error: 0.0066
#
# Epoch 00176: val_mean_squared_error did not improve from 0.00540
# Epoch 177/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0082 - val_mean_squared_error: 0.0067
#
# Epoch 00177: val_mean_squared_error did not improve from 0.00540
# Epoch 178/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0070 - val_mean_squared_error: 0.0055
#
# Epoch 00178: val_mean_squared_error did not improve from 0.00540
# Epoch 179/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0080 - val_mean_squared_error: 0.0065
#
# Epoch 00179: val_mean_squared_error did not improve from 0.00540
# Epoch 180/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0074 - val_mean_squared_error: 0.0059
#
# Epoch 00180: val_mean_squared_error did not improve from 0.00540
# Epoch 181/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0080 - val_mean_squared_error: 0.0065
#
# Epoch 00181: val_mean_squared_error did not improve from 0.00540
# Epoch 182/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0087 - val_mean_squared_error: 0.0072
#
# Epoch 00182: val_mean_squared_error did not improve from 0.00540
# Epoch 183/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0078 - val_mean_squared_error: 0.0063
#
# Epoch 00183: val_mean_squared_error did not improve from 0.00540
# Epoch 184/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0086 - val_mean_squared_error: 0.0071
#
# Epoch 00184: val_mean_squared_error did not improve from 0.00540
# Epoch 185/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0083 - val_mean_squared_error: 0.0069
#
# Epoch 00185: val_mean_squared_error did not improve from 0.00540
# Epoch 186/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0082 - val_mean_squared_error: 0.0067
#
# Epoch 00186: val_mean_squared_error did not improve from 0.00540
# Epoch 187/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0079 - val_mean_squared_error: 0.0064
#
# Epoch 00187: val_mean_squared_error did not improve from 0.00540
# Epoch 188/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0084 - val_mean_squared_error: 0.0069
#
# Epoch 00188: val_mean_squared_error did not improve from 0.00540
# Epoch 189/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0093 - val_mean_squared_error: 0.0078
#
# Epoch 00189: val_mean_squared_error did not improve from 0.00540
# Epoch 190/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0077 - val_mean_squared_error: 0.0062
#
# Epoch 00190: val_mean_squared_error did not improve from 0.00540
# Epoch 191/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0090 - val_mean_squared_error: 0.0075
#
# Epoch 00191: val_mean_squared_error did not improve from 0.00540
# Epoch 192/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0080 - val_mean_squared_error: 0.0065
#
# Epoch 00192: val_mean_squared_error did not improve from 0.00540
# Epoch 193/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0079 - val_mean_squared_error: 0.0064
#
# Epoch 00193: val_mean_squared_error did not improve from 0.00540
# Epoch 194/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0078 - val_mean_squared_error: 0.0063
#
# Epoch 00194: val_mean_squared_error did not improve from 0.00540
# Epoch 195/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0080 - val_mean_squared_error: 0.0065
#
# Epoch 00195: val_mean_squared_error did not improve from 0.00540
# Epoch 196/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0029 - val_loss: 0.0082 - val_mean_squared_error: 0.0067
#
# Epoch 00196: val_mean_squared_error did not improve from 0.00540
# Epoch 197/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0076 - val_mean_squared_error: 0.0061
#
# Epoch 00197: val_mean_squared_error did not improve from 0.00540
# Epoch 198/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0044 - mean_squared_error: 0.0029 - val_loss: 0.0079 - val_mean_squared_error: 0.0064
#
# Epoch 00198: val_mean_squared_error did not improve from 0.00540
# Epoch 199/200
# 1414/1414 [==============================] - 4s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0028 - val_loss: 0.0096 - val_mean_squared_error: 0.0081
#
# Epoch 00199: val_mean_squared_error did not improve from 0.00540
# Epoch 200/200
# 1414/1414 [==============================] - 5s 3ms/step - loss: 0.0045 - mean_squared_error: 0.0030 - val_loss: 0.0086 - val_mean_squared_error: 0.0071
#
# Epoch 00200: val_mean_squared_error did not improve from 0.00540

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('MSE')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
filepath="weight_troika.hdf5"
aemodel.load_weights(filepath)

# %%
#Predict test set
predict_num = 1000
X_predict = X_train_noise[predict_num, :, :]
predict_res = aemodel.predict(np.expand_dims(X_predict, axis=0))

plt.subplot(3, 1, 1)
plt.plot(range(1000), X_train_noise[predict_num])
plt.title('Signal + WGN')
plt.subplot(3, 1, 2)
plt.plot(range(1000), X_train[predict_num])
plt.title('The original signal')
plt.subplot(3, 1, 3)
plt.plot(range(1000), predict_res[0])
plt.title('Denoise')
plt.show()

# %%
#aemodel.summary()

# %%
dropout_rate = 0.2
layer_out = aemodel.layers[16].output

if K.image_dim_ordering() == 'channels_first':
	add_axis = 1
else:
	add_axis = -1
    
weight_decay = 1e-4

newlayer = BatchNormalization(axis=add_axis, 
                              gamma_regularizer=l2(weight_decay),
                             beta_regularizer=l2(weight_decay))(layer_out)
newlayer = Activation('relu')(newlayer)
newlayer = UpSampling1D(4)(layer_out)
newlayer = Conv1D(64, 4, padding='same',
                    kernel_initializer='glorot_uniform',
                    kernel_regularizer=l2(1e-4))(newlayer)
newlayer = Dropout(dropout_rate)(newlayer)
newlayer = MaxPooling1D(pool_size=2)(newlayer)
#newlayer = UpSampling1D(2)(newlayer)

newlayer = BatchNormalization(axis=add_axis, 
                              gamma_regularizer=l2(weight_decay),
                             beta_regularizer=l2(weight_decay))(newlayer)
newlayer = Activation('relu')(newlayer)
newlayer = Conv1D(256, 4, padding='same',
                    kernel_initializer='glorot_uniform',
                    kernel_regularizer=l2(1e-4))(newlayer)
newlayer = Dropout(dropout_rate)(newlayer)
newlayer = MaxPooling1D(pool_size=2)(newlayer)

newlayer = BatchNormalization(axis=add_axis, 
                              gamma_regularizer=l2(weight_decay),
                             beta_regularizer=l2(weight_decay))(newlayer)
newlayer = Activation('relu')(newlayer)
newlayer = Conv1D(128, 4, padding='same',
                    kernel_initializer='glorot_uniform',
                    kernel_regularizer=l2(1e-4))(newlayer)
newlayer = Dropout(dropout_rate)(newlayer)
newlayer = MaxPooling1D(pool_size=2)(newlayer)

newlayer = BatchNormalization(axis=add_axis, 
                              gamma_regularizer=l2(weight_decay),
                             beta_regularizer=l2(weight_decay))(newlayer)
newlayer = Activation('relu')(newlayer)
newlayer = Conv1D(64, 4, padding='same',
                    kernel_initializer='glorot_uniform',
                    kernel_regularizer=l2(1e-4))(newlayer)
newlayer = Dropout(dropout_rate)(newlayer)
newlayer = MaxPooling1D(pool_size=2)(newlayer)

newlayer = BatchNormalization(axis=add_axis, 
                              gamma_regularizer=l2(weight_decay),
                             beta_regularizer=l2(weight_decay))(newlayer)
newlayer = Activation('relu')(newlayer)
newlayer = Conv1D(16, 4, padding='same',
                    kernel_initializer='glorot_uniform',
                    kernel_regularizer=l2(1e-4))(newlayer)
newlayer = Dropout(dropout_rate)(newlayer)
#newlayer = GlobalAveragePooling1D()(newlayer)

newlayer = Flatten()(newlayer)
newlayer = Dense(64, activation='relu')(newlayer)
newlayer = Dropout(dropout_rate)(newlayer)
newlayer = Dense(16, activation='relu')(newlayer)
newlayer = Dropout(dropout_rate)(newlayer)

out = Dense(1, activation='sigmoid', 
               kernel_initializer='glorot_uniform')(newlayer)

finalmodel = Model(input=aemodel.input, output=out)

# Freeze the layers
for layer in finalmodel.layers[:10]:
    layer.trainable = False
# Out:
# /Users/xufanxiong/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:72: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`

# %%
optm = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=3*10**(-4))
finalmodel.compile(loss= "mse", 
              optimizer=optm, 
              metrics=["mse"])

# %%
filepath="weight_troika_final.hdf5"
checkpoint = ModelCheckpoint(filepath, 
                             monitor='val_mean_squared_error', 
                             verbose=1, 
                              save_best_only=True,
                             mode='min')
callbacks_list = [checkpoint]
history = finalmodel.fit(X_train, y_train, 
                    epochs=100, 
                    batch_size=128, 
                    validation_split=0.2, 
                    callbacks=callbacks_list,
                    shuffle=True,
                    verbose=1)
# Out:
# Train on 1414 samples, validate on 354 samples
# Epoch 1/100
#  640/1414 [============>.................] - ETA: 4s - loss: 0.1569 - mean_squared_error: 0.0580
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-f3b7646ac128> in <module>()
#      12                     callbacks=callbacks_list,
#      13                     shuffle=True,
# ---> 14                     verbose=1)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1040                                         initial_epoch=initial_epoch,
#    1041                                         steps_per_epoch=steps_per_epoch,
# -> 1042                                         validation_steps=validation_steps)
#    1043
#    1044     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 if not isinstance(outs, list):
#     201                     outs = [outs]
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('MSE')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
finalmodel.load_weights('weight_troika_final.hdf5')

# %%
#Evaluate
#eva = finalmodel.evaluate(X_test, Y_test, batch_size=32, verbose=1, sample_weight=None)
#print('loss = ' + str(eva[0]))
#print('Test MSE = ' + str(eva[1]))

# %%
pred_label = finalmodel.predict(X_train)

# %%
mod_model, y_mod_label = modify_model((1000, 5), y_train, pred_label, 8)
# Out:
# /Users/xufanxiong/Desktop/Troika_1/modify_model.py:106: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   model = Model(input=inputs, output=mod_layers)

# %%
optm = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=3*10**(-4))
mod_model.compile(loss= "mse", 
              optimizer=optm, 
              metrics=["mse"])

# %%
filepath="weight_troika_final_modify.hdf5"
checkpoint = ModelCheckpoint(filepath, 
                             monitor='val_mean_squared_error', 
                             verbose=1, 
                             save_best_only=True,
                             mode='min')
callbacks_list = [checkpoint]
history = mod_model.fit(X_train, y_mod_label, 
                    epochs=100, 
                    batch_size=128, 
                    validation_split=0.2, 
                    callbacks=callbacks_list,
                    shuffle=True,
                    verbose=1)
# Out:
# Train on 1414 samples, validate on 354 samples
# Epoch 1/100
# 1414/1414 [==============================] - 9s 7ms/step - loss: 2.9133 - mean_squared_error: 2.7941 - val_loss: 0.1535 - val_mean_squared_error: 0.0339
#
# Epoch 00001: val_mean_squared_error improved from inf to 0.03389, saving model to weight_troika_final_modify.hdf5
# Epoch 2/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.3473 - mean_squared_error: 0.2276 - val_loss: 0.1440 - val_mean_squared_error: 0.0240
#
# Epoch 00002: val_mean_squared_error improved from 0.03389 to 0.02403, saving model to weight_troika_final_modify.hdf5
# Epoch 3/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.2450 - mean_squared_error: 0.1250 - val_loss: 0.1430 - val_mean_squared_error: 0.0230
#
# Epoch 00003: val_mean_squared_error improved from 0.02403 to 0.02295, saving model to weight_troika_final_modify.hdf5
# Epoch 4/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1792 - mean_squared_error: 0.0592 - val_loss: 0.1404 - val_mean_squared_error: 0.0203
#
# Epoch 00004: val_mean_squared_error improved from 0.02295 to 0.02034, saving model to weight_troika_final_modify.hdf5
# Epoch 5/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1612 - mean_squared_error: 0.0412 - val_loss: 0.1425 - val_mean_squared_error: 0.0225
#
# Epoch 00005: val_mean_squared_error did not improve from 0.02034
# Epoch 6/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1542 - mean_squared_error: 0.0343 - val_loss: 0.1438 - val_mean_squared_error: 0.0239
#
# Epoch 00006: val_mean_squared_error did not improve from 0.02034
# Epoch 7/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1434 - mean_squared_error: 0.0235 - val_loss: 0.1440 - val_mean_squared_error: 0.0242
#
# Epoch 00007: val_mean_squared_error did not improve from 0.02034
# Epoch 8/100
# 1414/1414 [==============================] - 8s 6ms/step - loss: 0.1434 - mean_squared_error: 0.0235 - val_loss: 0.1452 - val_mean_squared_error: 0.0255
#
# Epoch 00008: val_mean_squared_error did not improve from 0.02034
# Epoch 9/100
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.1406 - mean_squared_error: 0.0209 - val_loss: 0.1440 - val_mean_squared_error: 0.0244
#
# Epoch 00009: val_mean_squared_error did not improve from 0.02034
# Epoch 10/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1405 - mean_squared_error: 0.0208 - val_loss: 0.1453 - val_mean_squared_error: 0.0257
#
# Epoch 00010: val_mean_squared_error did not improve from 0.02034
# Epoch 11/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1400 - mean_squared_error: 0.0204 - val_loss: 0.1449 - val_mean_squared_error: 0.0254
#
# Epoch 00011: val_mean_squared_error did not improve from 0.02034
# Epoch 12/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1393 - mean_squared_error: 0.0199 - val_loss: 0.1449 - val_mean_squared_error: 0.0256
#
# Epoch 00012: val_mean_squared_error did not improve from 0.02034
# Epoch 13/100
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.1384 - mean_squared_error: 0.0191 - val_loss: 0.1443 - val_mean_squared_error: 0.0250
#
# Epoch 00013: val_mean_squared_error did not improve from 0.02034
# Epoch 14/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1374 - mean_squared_error: 0.0182 - val_loss: 0.1453 - val_mean_squared_error: 0.0261
#
# Epoch 00014: val_mean_squared_error did not improve from 0.02034
# Epoch 15/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1361 - mean_squared_error: 0.0169 - val_loss: 0.1463 - val_mean_squared_error: 0.0273
#
# Epoch 00015: val_mean_squared_error did not improve from 0.02034
# Epoch 16/100
# 1414/1414 [==============================] - 8s 6ms/step - loss: 0.1362 - mean_squared_error: 0.0172 - val_loss: 0.1468 - val_mean_squared_error: 0.0279
#
# Epoch 00016: val_mean_squared_error did not improve from 0.02034
# Epoch 17/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1360 - mean_squared_error: 0.0171 - val_loss: 0.1461 - val_mean_squared_error: 0.0272
#
# Epoch 00017: val_mean_squared_error did not improve from 0.02034
# Epoch 18/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1365 - mean_squared_error: 0.0178 - val_loss: 0.1433 - val_mean_squared_error: 0.0246
#
# Epoch 00018: val_mean_squared_error did not improve from 0.02034
# Epoch 19/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1357 - mean_squared_error: 0.0170 - val_loss: 0.1435 - val_mean_squared_error: 0.0250
#
# Epoch 00019: val_mean_squared_error did not improve from 0.02034
# Epoch 20/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1351 - mean_squared_error: 0.0166 - val_loss: 0.1444 - val_mean_squared_error: 0.0259
#
# Epoch 00020: val_mean_squared_error did not improve from 0.02034
# Epoch 21/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1349 - mean_squared_error: 0.0165 - val_loss: 0.1433 - val_mean_squared_error: 0.0250
#
# Epoch 00021: val_mean_squared_error did not improve from 0.02034
# Epoch 22/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1338 - mean_squared_error: 0.0156 - val_loss: 0.1434 - val_mean_squared_error: 0.0252
#
# Epoch 00022: val_mean_squared_error did not improve from 0.02034
# Epoch 23/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1339 - mean_squared_error: 0.0158 - val_loss: 0.1416 - val_mean_squared_error: 0.0235
#
# Epoch 00023: val_mean_squared_error did not improve from 0.02034
# Epoch 24/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1336 - mean_squared_error: 0.0156 - val_loss: 0.1418 - val_mean_squared_error: 0.0239
#
# Epoch 00024: val_mean_squared_error did not improve from 0.02034
# Epoch 25/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1350 - mean_squared_error: 0.0171 - val_loss: 0.1418 - val_mean_squared_error: 0.0240
#
# Epoch 00025: val_mean_squared_error did not improve from 0.02034
# Epoch 26/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1342 - mean_squared_error: 0.0165 - val_loss: 0.1412 - val_mean_squared_error: 0.0236
#
# Epoch 00026: val_mean_squared_error did not improve from 0.02034
# Epoch 27/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1336 - mean_squared_error: 0.0160 - val_loss: 0.1423 - val_mean_squared_error: 0.0248
#
# Epoch 00027: val_mean_squared_error did not improve from 0.02034
# Epoch 28/100
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.1330 - mean_squared_error: 0.0156 - val_loss: 0.1425 - val_mean_squared_error: 0.0251
#
# Epoch 00028: val_mean_squared_error did not improve from 0.02034
# Epoch 29/100
# 1414/1414 [==============================] - 8s 6ms/step - loss: 0.1329 - mean_squared_error: 0.0156 - val_loss: 0.1428 - val_mean_squared_error: 0.0256
#
# Epoch 00029: val_mean_squared_error did not improve from 0.02034
# Epoch 30/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1316 - mean_squared_error: 0.0145 - val_loss: 0.1446 - val_mean_squared_error: 0.0276
#
# Epoch 00030: val_mean_squared_error did not improve from 0.02034
# Epoch 31/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1322 - mean_squared_error: 0.0152 - val_loss: 0.1441 - val_mean_squared_error: 0.0272
#
# Epoch 00031: val_mean_squared_error did not improve from 0.02034
# Epoch 32/100
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.1318 - mean_squared_error: 0.0150 - val_loss: 0.1433 - val_mean_squared_error: 0.0265
#
# Epoch 00032: val_mean_squared_error did not improve from 0.02034
# Epoch 33/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1316 - mean_squared_error: 0.0149 - val_loss: 0.1430 - val_mean_squared_error: 0.0264
#
# Epoch 00033: val_mean_squared_error did not improve from 0.02034
# Epoch 34/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1313 - mean_squared_error: 0.0148 - val_loss: 0.1452 - val_mean_squared_error: 0.0287
#
# Epoch 00034: val_mean_squared_error did not improve from 0.02034
# Epoch 35/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1315 - mean_squared_error: 0.0151 - val_loss: 0.1418 - val_mean_squared_error: 0.0255
#
# Epoch 00035: val_mean_squared_error did not improve from 0.02034
# Epoch 36/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1310 - mean_squared_error: 0.0147 - val_loss: 0.1429 - val_mean_squared_error: 0.0268
#
# Epoch 00036: val_mean_squared_error did not improve from 0.02034
# Epoch 37/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1312 - mean_squared_error: 0.0151 - val_loss: 0.1441 - val_mean_squared_error: 0.0281
#
# Epoch 00037: val_mean_squared_error did not improve from 0.02034
# Epoch 38/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1312 - mean_squared_error: 0.0153 - val_loss: 0.1444 - val_mean_squared_error: 0.0286
#
# Epoch 00038: val_mean_squared_error did not improve from 0.02034
# Epoch 39/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1303 - mean_squared_error: 0.0146 - val_loss: 0.1422 - val_mean_squared_error: 0.0265
#
# Epoch 00039: val_mean_squared_error did not improve from 0.02034
# Epoch 40/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1298 - mean_squared_error: 0.0142 - val_loss: 0.1414 - val_mean_squared_error: 0.0259
#
# Epoch 00040: val_mean_squared_error did not improve from 0.02034
# Epoch 41/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1286 - mean_squared_error: 0.0132 - val_loss: 0.1429 - val_mean_squared_error: 0.0276
#
# Epoch 00041: val_mean_squared_error did not improve from 0.02034
# Epoch 42/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1285 - mean_squared_error: 0.0132 - val_loss: 0.1424 - val_mean_squared_error: 0.0272
#
# Epoch 00042: val_mean_squared_error did not improve from 0.02034
# Epoch 43/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1289 - mean_squared_error: 0.0138 - val_loss: 0.1418 - val_mean_squared_error: 0.0268
#
# Epoch 00043: val_mean_squared_error did not improve from 0.02034
# Epoch 44/100
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.1284 - mean_squared_error: 0.0134 - val_loss: 0.1431 - val_mean_squared_error: 0.0282
#
# Epoch 00044: val_mean_squared_error did not improve from 0.02034
# Epoch 45/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1277 - mean_squared_error: 0.0129 - val_loss: 0.1437 - val_mean_squared_error: 0.0291
#
# Epoch 00045: val_mean_squared_error did not improve from 0.02034
# Epoch 46/100
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.1276 - mean_squared_error: 0.0130 - val_loss: 0.1426 - val_mean_squared_error: 0.0281
#
# Epoch 00046: val_mean_squared_error did not improve from 0.02034
# Epoch 47/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1277 - mean_squared_error: 0.0132 - val_loss: 0.1407 - val_mean_squared_error: 0.0264
#
# Epoch 00047: val_mean_squared_error did not improve from 0.02034
# Epoch 48/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1273 - mean_squared_error: 0.0130 - val_loss: 0.1402 - val_mean_squared_error: 0.0261
#
# Epoch 00048: val_mean_squared_error did not improve from 0.02034
# Epoch 49/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1268 - mean_squared_error: 0.0127 - val_loss: 0.1418 - val_mean_squared_error: 0.0278
#
# Epoch 00049: val_mean_squared_error did not improve from 0.02034
# Epoch 50/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1263 - mean_squared_error: 0.0123 - val_loss: 0.1426 - val_mean_squared_error: 0.0288
#
# Epoch 00050: val_mean_squared_error did not improve from 0.02034
# Epoch 51/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1261 - mean_squared_error: 0.0124 - val_loss: 0.1456 - val_mean_squared_error: 0.0320
#
# Epoch 00051: val_mean_squared_error did not improve from 0.02034
# Epoch 52/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1267 - mean_squared_error: 0.0132 - val_loss: 0.1431 - val_mean_squared_error: 0.0296
#
# Epoch 00052: val_mean_squared_error did not improve from 0.02034
# Epoch 53/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1257 - mean_squared_error: 0.0123 - val_loss: 0.1432 - val_mean_squared_error: 0.0299
#
# Epoch 00053: val_mean_squared_error did not improve from 0.02034
# Epoch 54/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1254 - mean_squared_error: 0.0122 - val_loss: 0.1435 - val_mean_squared_error: 0.0303
#
# Epoch 00054: val_mean_squared_error did not improve from 0.02034
# Epoch 55/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1245 - mean_squared_error: 0.0114 - val_loss: 0.1439 - val_mean_squared_error: 0.0310
#
# Epoch 00055: val_mean_squared_error did not improve from 0.02034
# Epoch 56/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1249 - mean_squared_error: 0.0120 - val_loss: 0.1438 - val_mean_squared_error: 0.0311
#
# Epoch 00056: val_mean_squared_error did not improve from 0.02034
# Epoch 57/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1245 - mean_squared_error: 0.0118 - val_loss: 0.1443 - val_mean_squared_error: 0.0317
#
# Epoch 00057: val_mean_squared_error did not improve from 0.02034
# Epoch 58/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1247 - mean_squared_error: 0.0122 - val_loss: 0.1453 - val_mean_squared_error: 0.0329
#
# Epoch 00058: val_mean_squared_error did not improve from 0.02034
# Epoch 59/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1240 - mean_squared_error: 0.0116 - val_loss: 0.1449 - val_mean_squared_error: 0.0327
#
# Epoch 00059: val_mean_squared_error did not improve from 0.02034
# Epoch 60/100
# 1414/1414 [==============================] - 8s 6ms/step - loss: 0.1236 - mean_squared_error: 0.0114 - val_loss: 0.1438 - val_mean_squared_error: 0.0317
#
# Epoch 00060: val_mean_squared_error did not improve from 0.02034
# Epoch 61/100
# 1414/1414 [==============================] - 8s 6ms/step - loss: 0.1234 - mean_squared_error: 0.0115 - val_loss: 0.1427 - val_mean_squared_error: 0.0308
#
# Epoch 00061: val_mean_squared_error did not improve from 0.02034
# Epoch 62/100
# 1414/1414 [==============================] - 8s 6ms/step - loss: 0.1227 - mean_squared_error: 0.0109 - val_loss: 0.1442 - val_mean_squared_error: 0.0325
#
# Epoch 00062: val_mean_squared_error did not improve from 0.02034
# Epoch 63/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1229 - mean_squared_error: 0.0113 - val_loss: 0.1433 - val_mean_squared_error: 0.0318
#
# Epoch 00063: val_mean_squared_error did not improve from 0.02034
# Epoch 64/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1231 - mean_squared_error: 0.0116 - val_loss: 0.1461 - val_mean_squared_error: 0.0348
#
# Epoch 00064: val_mean_squared_error did not improve from 0.02034
# Epoch 65/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1219 - mean_squared_error: 0.0107 - val_loss: 0.1464 - val_mean_squared_error: 0.0353
#
# Epoch 00065: val_mean_squared_error did not improve from 0.02034
# Epoch 66/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1216 - mean_squared_error: 0.0105 - val_loss: 0.1490 - val_mean_squared_error: 0.0380
#
# Epoch 00066: val_mean_squared_error did not improve from 0.02034
# Epoch 67/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1208 - mean_squared_error: 0.0099 - val_loss: 0.1494 - val_mean_squared_error: 0.0386
#
# Epoch 00067: val_mean_squared_error did not improve from 0.02034
# Epoch 68/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1208 - mean_squared_error: 0.0100 - val_loss: 0.1465 - val_mean_squared_error: 0.0359
#
# Epoch 00068: val_mean_squared_error did not improve from 0.02034
# Epoch 69/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1204 - mean_squared_error: 0.0098 - val_loss: 0.1466 - val_mean_squared_error: 0.0361
#
# Epoch 00069: val_mean_squared_error did not improve from 0.02034
# Epoch 70/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1200 - mean_squared_error: 0.0096 - val_loss: 0.1468 - val_mean_squared_error: 0.0366
#
# Epoch 00070: val_mean_squared_error did not improve from 0.02034
# Epoch 71/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1193 - mean_squared_error: 0.0091 - val_loss: 0.1514 - val_mean_squared_error: 0.0414
#
# Epoch 00071: val_mean_squared_error did not improve from 0.02034
# Epoch 72/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1193 - mean_squared_error: 0.0093 - val_loss: 0.1455 - val_mean_squared_error: 0.0356
#
# Epoch 00072: val_mean_squared_error did not improve from 0.02034
# Epoch 73/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1192 - mean_squared_error: 0.0094 - val_loss: 0.1487 - val_mean_squared_error: 0.0390
#
# Epoch 00073: val_mean_squared_error did not improve from 0.02034
# Epoch 74/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1188 - mean_squared_error: 0.0092 - val_loss: 0.1492 - val_mean_squared_error: 0.0397
#
# Epoch 00074: val_mean_squared_error did not improve from 0.02034
# Epoch 75/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1182 - mean_squared_error: 0.0088 - val_loss: 0.1499 - val_mean_squared_error: 0.0406
#
# Epoch 00075: val_mean_squared_error did not improve from 0.02034
# Epoch 76/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1184 - mean_squared_error: 0.0091 - val_loss: 0.1584 - val_mean_squared_error: 0.0493
#
# Epoch 00076: val_mean_squared_error did not improve from 0.02034
# Epoch 77/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1181 - mean_squared_error: 0.0090 - val_loss: 0.1496 - val_mean_squared_error: 0.0406
#
# Epoch 00077: val_mean_squared_error did not improve from 0.02034
# Epoch 78/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1176 - mean_squared_error: 0.0087 - val_loss: 0.1589 - val_mean_squared_error: 0.0501
#
# Epoch 00078: val_mean_squared_error did not improve from 0.02034
# Epoch 79/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1176 - mean_squared_error: 0.0089 - val_loss: 0.1519 - val_mean_squared_error: 0.0433
#
# Epoch 00079: val_mean_squared_error did not improve from 0.02034
# Epoch 80/100
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.1173 - mean_squared_error: 0.0088 - val_loss: 0.1524 - val_mean_squared_error: 0.0441
#
# Epoch 00080: val_mean_squared_error did not improve from 0.02034
# Epoch 81/100
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.1165 - mean_squared_error: 0.0082 - val_loss: 0.1534 - val_mean_squared_error: 0.0452
#
# Epoch 00081: val_mean_squared_error did not improve from 0.02034
# Epoch 82/100
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.1162 - mean_squared_error: 0.0081 - val_loss: 0.1537 - val_mean_squared_error: 0.0457
#
# Epoch 00082: val_mean_squared_error did not improve from 0.02034
# Epoch 83/100
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.1162 - mean_squared_error: 0.0083 - val_loss: 0.1492 - val_mean_squared_error: 0.0414
#
# Epoch 00083: val_mean_squared_error did not improve from 0.02034
# Epoch 84/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1156 - mean_squared_error: 0.0079 - val_loss: 0.1546 - val_mean_squared_error: 0.0470
#
# Epoch 00084: val_mean_squared_error did not improve from 0.02034
# Epoch 85/100
# 1414/1414 [==============================] - 8s 6ms/step - loss: 0.1155 - mean_squared_error: 0.0079 - val_loss: 0.1501 - val_mean_squared_error: 0.0427
#
# Epoch 00085: val_mean_squared_error did not improve from 0.02034
# Epoch 86/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1155 - mean_squared_error: 0.0081 - val_loss: 0.1504 - val_mean_squared_error: 0.0431
#
# Epoch 00086: val_mean_squared_error did not improve from 0.02034
# Epoch 87/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1151 - mean_squared_error: 0.0080 - val_loss: 0.1536 - val_mean_squared_error: 0.0466
#
# Epoch 00087: val_mean_squared_error did not improve from 0.02034
# Epoch 88/100
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.1146 - mean_squared_error: 0.0076 - val_loss: 0.1469 - val_mean_squared_error: 0.0400
#
# Epoch 00088: val_mean_squared_error did not improve from 0.02034
# Epoch 89/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1146 - mean_squared_error: 0.0078 - val_loss: 0.1534 - val_mean_squared_error: 0.0468
#
# Epoch 00089: val_mean_squared_error did not improve from 0.02034
# Epoch 90/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1143 - mean_squared_error: 0.0077 - val_loss: 0.1453 - val_mean_squared_error: 0.0388
#
# Epoch 00090: val_mean_squared_error did not improve from 0.02034
# Epoch 91/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1136 - mean_squared_error: 0.0072 - val_loss: 0.1455 - val_mean_squared_error: 0.0392
#
# Epoch 00091: val_mean_squared_error did not improve from 0.02034
# Epoch 92/100
# 1414/1414 [==============================] - 8s 6ms/step - loss: 0.1134 - mean_squared_error: 0.0072 - val_loss: 0.1476 - val_mean_squared_error: 0.0415
#
# Epoch 00092: val_mean_squared_error did not improve from 0.02034
# Epoch 93/100
# 1414/1414 [==============================] - 8s 6ms/step - loss: 0.1133 - mean_squared_error: 0.0073 - val_loss: 0.1408 - val_mean_squared_error: 0.0349
#
# Epoch 00093: val_mean_squared_error did not improve from 0.02034
# Epoch 94/100
# 1414/1414 [==============================] - 8s 6ms/step - loss: 0.1128 - mean_squared_error: 0.0070 - val_loss: 0.1445 - val_mean_squared_error: 0.0388
#
# Epoch 00094: val_mean_squared_error did not improve from 0.02034
# Epoch 95/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1121 - mean_squared_error: 0.0065 - val_loss: 0.1399 - val_mean_squared_error: 0.0344
#
# Epoch 00095: val_mean_squared_error did not improve from 0.02034
# Epoch 96/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1121 - mean_squared_error: 0.0066 - val_loss: 0.1406 - val_mean_squared_error: 0.0353
#
# Epoch 00096: val_mean_squared_error did not improve from 0.02034
# Epoch 97/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1112 - mean_squared_error: 0.0060 - val_loss: 0.1416 - val_mean_squared_error: 0.0365
#
# Epoch 00097: val_mean_squared_error did not improve from 0.02034
# Epoch 98/100
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.1113 - mean_squared_error: 0.0062 - val_loss: 0.1412 - val_mean_squared_error: 0.0363
#
# Epoch 00098: val_mean_squared_error did not improve from 0.02034
# Epoch 99/100
# 1414/1414 [==============================] - 7s 5ms/step - loss: 0.1111 - mean_squared_error: 0.0063 - val_loss: 0.1381 - val_mean_squared_error: 0.0334
#
# Epoch 00099: val_mean_squared_error did not improve from 0.02034
# Epoch 100/100
# 1414/1414 [==============================] - 8s 5ms/step - loss: 0.1106 - mean_squared_error: 0.0059 - val_loss: 0.1419 - val_mean_squared_error: 0.0374
#
# Epoch 00100: val_mean_squared_error did not improve from 0.02034

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('MSE')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
mod_model.load_weights('weight_troika_final_modify.hdf5')

# %%
#Import Test
X_test = sio.loadmat('Training_data/DATA_03_TYPE02.mat')
y_test = sio.loadmat('Training_data/DATA_03_TYPE02_BPMtrace.mat')
X_test = X_test['sig'].T
y_test = y_test['BPM0']
print('The shape of X_test is: ' + str(X_test.shape))
print('The shape of y_test is: ' + str(y_test.shape))
# Out:
# The shape of X_test is: (35989, 6)
# The shape of y_test is: (140, 1)

# %%
#Split data
tem = X_test[:, 1:]
X_test = np.zeros((y_test.shape[0], 125*8, 5))
k = 0

for i in range(y_test.shape[0]):
    X_test[i, :, :] = tem[k:(k+125*8), :]
    k += 2*125
    
tem = 0

y_test = (y_test-50)/150
X_test = normali(X_test)

print('The shape of X_test is: ' + str(X_test.shape))
print('The shape of y_test is: ' + str(y_test.shape))
# Out:
# The shape of X_test is: (140, 1000, 5)
# The shape of y_test is: (140, 1)

# %%
predict = finalmodel.predict(X_test)
predict_mod = mod_model.predict(X_test)

# %%
plt.subplot(211)
plt.plot(y_test)
plt.plot(predict)
plt.title('Before modify')
plt.subplot(212)
plt.plot(y_test)
plt.plot(predict+predict_mod)
plt.title('After modify')
plt.show()
